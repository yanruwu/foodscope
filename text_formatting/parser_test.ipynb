# %%
import spacy
import re
import pandas as pd
import numpy as np

nlp = spacy.load("en_core_web_sm")

ESSENTIAL_WORDS = {"avocado", "all", "baking"}
ESSENTIAL_ADJECTIVES = {"olive", "canola", "coconut", "sesame", "almond", "hot", "rosemary", "green", "red", "yellow", "black", "zest"}
ESSENTIAL_ADV = {"baking", "all", "rising"}  
EXCLUDED_WORDS = {"taste", "needed", "optional", "divided", "degrees", "f", "c", "halves", "inch", "pieces"}

# Aquí indicamos qué sustantivos consideramos "compound" 
# cuando van precedidos por un adjetivo o un compound. 
# Así "chili powder" o "garlic powder" se mantienen juntos.
TARGET_NOUNS = {"powder", "oil", "sauce", "milk", "paste", "meal", "flour"}

def clean_ingredient_with_pos(text: str) -> str:
    """
    1) Separa guiones ("freeze-dried" -> "freeze dried") para tokenizar mejor.
    2) Usa spaCy para POS tagging + dependencias.
    3) Combina ADJ/compound + NOUN cuando NOUN está en TARGET_NOUNS (por ej. "chili powder").
    4) Elimina palabras EXCLUDED, etc.
    5) Lemmatiza sustantivos para unificar singular/plural ("eggs" -> "egg").
    6) Reconstruye en un único string limpio.
    """
    text = text.replace("-", " ")
    doc = nlp(text)

    processed = set()  # para marcar tokens ya procesados
    keep_tokens = []

    for token in doc:
        # Si ya lo hemos procesado en una combinación anterior, lo saltamos
        if token.i in processed:
            continue

        lemma = token.lemma_.lower()  # para comparaciones en minúscula

        # 1) Si está en la lista EXCLUDED, ignoramos este token
        if lemma in EXCLUDED_WORDS:
            continue

        # 2) Detectar si este token es un adjetivo (ADJ) o compound (dep_) 
        #    que modifica a un sustantivo "target" (e.g. powder)
        #    - token.dep_ puede ser 'amod' (adjectival modifier) o 'compound'
        #    - token.head es el NOUN al que modifica
        if token.dep_ in ("amod", "compound") and token.head.pos_ == "NOUN":
            head_lemma = token.head.lemma_.lower()
            if head_lemma in TARGET_NOUNS:
                # => Combinamos p.ej. "chili" + "powder" => "chili powder"
                combined = f"{token.lemma_.lower()} {head_lemma}"
                keep_tokens.append(combined)
                
                # Marcamos ambos tokens como procesados
                processed.add(token.i)
                processed.add(token.head.i)
                continue

        # 3) Si es un NOUN o PROPN, lo mantenemos (lematizado) 
        #    a menos que se haya procesado en la combinación anterior
        if token.pos_ in ["NOUN", "PROPN"] and token.i not in processed:
            # Lematizamos para unificar singular/plural
            keep_tokens.append(token.lemma_)

        # 4) Si es un ADJ y está en ESSENTIAL_ADJECTIVES, lo guardamos
        elif token.pos_ == "ADJ":
            if lemma in ESSENTIAL_ADJECTIVES:
                keep_tokens.append(token.lemma_)

        # 5) Si es un ADV y está en ESSENTIAL_ADV, lo guardamos
        elif token.pos_ == "ADV":
            if lemma in ESSENTIAL_ADV:
                keep_tokens.append(token.lemma_)

        # 6) Si es una palabra "esencial" por su lemma (e.g. "avocado"), la guardamos
        elif lemma in ESSENTIAL_WORDS:
            keep_tokens.append(token.lemma_)

    # Reconstruimos y limpiamos espacios, etc.
    cleaned = " ".join(keep_tokens)
    cleaned = re.sub(r"\s+", " ", cleaned).strip(",. ")

    return cleaned

# %%
recipes = pd.read_json(r"..\recetas_scrapper\recetas_allrecipes.jsonl", lines = True)

# %%
ing_list = [r["nombre"] for r in recipes.loc[74:, "ingredientes"]]

# %%
all_ing_list = [item for sublist in ing_list for item in sublist]

# %%
from tqdm import tqdm
clean_ing_list = []
for item in all_ing_list:
    clean_ing = clean_ingredient_with_pos(item)
    clean_ing_list.append(clean_ing)

    print(f"{item} -> {clean_ing}")
# Out:
# cabbage, thinly sliced -> cabbage
# white sugar -> sugar
# bacon -> bacon
# corn bread mix -> corn bread mix
# cayenne pepper -> cayenne pepper
# chopped onion -> onion
# fresh jalapeño peppers, seeded and julienned -> jalapeño pepper
# salt and pepper to taste -> salt pepper
# hard-cooked eggs, chopped -> egg
# avocados, peeled and chopped -> avocado
# seeded and chopped tomatoes -> tomato
# diced red onion -> red onion
# salt and ground black pepper to taste -> salt ground black pepper
# mayonnaise -> mayonnaise
# sour cream -> cream
# lemon juice -> lemon juice
# hot sauce (such as Frank's RedHot) -> hot sauce Frank RedHot
# dried great Northern beans, soaked overnight -> bean
# canola oil -> canola oil
# onion, chopped -> onion
# bacon, diced -> bacon
# garlic, minced -> garlic
# dried thyme -> thyme
# red pepper flakes -> red pepper flake
# pure maple syrup -> maple syrup
# tomato puree -> tomato puree
# Worcestershire sauce -> worcestershire sauce
# mustard powder -> mustard powder
# ham bone with some meat -> ham bone meat
# boiling water, or as needed -> boiling water
# bay leaf -> bay leaf
# apple cider vinegar -> apple cider vinegar
# hot pepper sauce, or to taste -> hot sauce pepper sauce
# salt and pepper to taste -> salt pepper
# Roma tomatoes -> Roma tomato
# capellini pasta -> pasta
# unsalted butter -> butter
# garlic, minced -> garlic
# salt and freshly ground black pepper to taste -> salt black pepper
# basil, thinly sliced -> basil
# Scotch bonnet chile pepper -> Scotch bonnet chile pepper
# bone-in chicken pieces, such as breasts, thighs, and drumsticks -> bone chicken piece breast thigh
# skinless, bone-in chicken breasts, cut in half -> skinless bone chicken breast half
# olive oil -> olive oil
# onion, finely chopped -> onion
# garlic, minced -> garlic
# uncooked long-grain white rice -> grain rice
# chicken broth -> chicken broth
# black-eyed peas, rinsed and drained -> black pea
# coconut milk -> coconut milk
# green onions, coarsely chopped -> green onion
# thyme, chopped -> thyme
# cabbage, cored and cut into large chunks -> cabbage chunk
# unsalted butter -> butter
# salt and ground black pepper to taste -> salt ground black pepper
# whole kernel corn -> kernel corn
# cream-style corn -> cream style corn
# sour cream -> cream
# dry corn muffin mix -> corn muffin mix
# salt and pepper to taste -> salt pepper
# oil, or as needed -> oil
# carrots, chopped -> carrot
# potato, chopped -> potato
# leeks, chopped (Optional) -> leeks
# onion, chopped -> onion
# sweet potato, shredded -> potato
# black beans, rinsed and drained -> black bean
# ground cumin -> ground cumin
# dried oregano -> oregano
# chili powder -> chili powder
# cayenne pepper -> cayenne pepper
# salt and ground black pepper to taste -> salt ground black pepper
# corn tortillas -> corn tortilla
# avocados - peeled, pitted, and mashed -> avocado
# crumbled queso fresco -> queso fresco
# salsa -> salsa
# finely chopped fresh cilantro -> cilantro
# lime juice, or to taste -> lime juice
# pineapple juice -> pineapple juice
# packed brown sugar -> sugar
# light soy sauce -> light sauce soy sauce
# chicken breast tenderloins or strips -> chicken breast tenderloin strip
# skewers -> skewer
# milk -> milk
# vanilla extract -> vanilla extract
# white sugar -> sugar
# cinnamon -> cinnamon
# eggs, beaten -> egg
# raspberry puree -> raspberry puree
# cream cheese, softened -> cream cheese
# French bread, cut into 1 inch slices -> bread slice
# butter -> butter
# confectioners' sugar for dusting -> confectioner sugar
# nutmeg, for topping -> nutmeg
# baby back pork ribs -> baby pork rib
# apricot preserves -> apricot
# soy sauce -> soy sauce
# packed light brown sugar -> sugar
# garlic powder -> garlic powder
# aluminum foil -> aluminum foil
# salt and ground black pepper to taste -> salt ground black pepper
# vegetable oil -> vegetable oil
# frozen hash brown potatoes -> potato
# diced cooked ham -> ham
# diced green chile peppers -> green chile pepper
# shredded Cheddar cheese, divided -> Cheddar cheese
# green chile enchilada sauce -> green chile sauce enchilada sauce
# flour tortillas -> flour tortilla
# water -> water
# uncooked white rice -> rice
# cabbage leaves -> cabbage
# lean ground beef -> ground beef
# chopped onion -> onion
# egg, slightly beaten -> egg
# condensed tomato soup, divided -> tomato soup
# salt -> salt
# ground black pepper -> ground black pepper
# sliced almonds, divided -> almond
# packed brown sugar -> sugar
# Dijon mustard -> Dijon mustard
# Brie cheese -> Brie cheese
# French baguette -> baguette
# cooking spray -> cooking spray
# cooking spray -> cooking spray
# garlic, minced -> garlic
# dried sage -> sage
# kosher salt -> salt
# ground black pepper -> ground black pepper
# pork loin -> pork loin
# apple cider vinegar -> apple cider vinegar
# water -> water
# soy sauce -> soy sauce
# brown sugar -> sugar
# Dijon mustard -> Dijon mustard
# cornstarch -> cornstarch
# ice -> ice
# gin (such as Citadelle) -> gin Citadelle
# 5 or 6 juniper berries -> juniper berry
# lime peel -> lime peel
# tonic water -> tonic water
# all-purpose flour -> all purpose flour
# baking powder -> powder
# white sugar -> sugar
# salt -> salt
# shortening -> shortening
# egg, beaten -> egg
# milk -> milk
# butter, melted -> butter
# bulk pork breakfast sausage (such as Jimmy Dean®) -> pork breakfast sausage Jimmy Dean ®
# butter -> butter
# all-purpose flour -> all purpose flour
# evaporated milk -> milk
# water -> water
# salt and ground black pepper to taste -> salt ground black pepper
# butter, divided -> butter
# boneless pork loin chops -> boneless pork loin chop
# chopped fresh thyme -> thyme
# onion, sliced into thin rings -> onion ring
# garlic, crushed -> garlic
# Cox apple, cored and cut into thick rings -> Cox apple ring
# red apple, cored and cut into rings -> red apple ring
# white sugar -> sugar
# dry hard cider -> cider
# salt and pepper to taste -> salt pepper
# heavy cream -> cream
# orange juice -> orange juice
# lemon juice -> lemon juice
# lime juice -> lime juice
# fresh cilantro, chopped -> fresh cilantro
# soy sauce -> soy sauce
# garlic, minced -> garlic
# chili powder -> chili powder
# ground cumin -> ground cumin
# ground paprika -> ground paprika
# ground black pepper -> ground black pepper
# finely chopped canned chipotle pepper  -> chipotle pepper
# dried oregano -> oregano
# olive oil -> olive oil
# flank steak -> flank steak
# pitted and halved loquats -> loquat
# white sugar -> sugar
# lemon juice -> lemon juice
# cauliflower, cut into 1-inch pieces -> cauliflower piece
# heavy cream -> cream
# freshly grated Parmesan cheese -> Parmesan cheese
# unsalted butter -> butter
# reduced-fat cream cheese -> cream cheese
# sea salt -> sea salt
# mayonnaise -> mayonnaise
# mayonnaise -> mayonnaise
# white sugar -> sugar
# salt -> salt
# onion powder -> onion powder
# ground mustard -> ground mustard
# paprika -> paprika
# ketchup -> ketchup
# red wine vinegar -> red wine vinegar
# Worcestershire sauce -> worcestershire sauce
# chopped onion -> onion
# garlic, minced -> garlic
# minced fresh ginger root -> ginger root
# lemon, juiced -> lemon
# soy sauce -> soy sauce
# sugar -> sugar
# white vinegar -> vinegar
# olive oil -> olive oil
# shallots, diced -> shallot
# diced carrots -> carrot
# chopped garlic -> garlic
# chopped fresh ginger -> ginger
# cubed butternut squash -> butternut squash
# chicken broth -> chicken broth
# curry powder -> curry powder
# honey -> honey
# ground white pepper -> ground pepper
# cayenne pepper -> cayenne pepper
# unsalted butter, softened -> butter
# brown sugar -> sugar
# white sugar -> sugar
# egg -> egg
# vanilla extract -> vanilla extract
# natural peanut butter -> peanut butter
# baking soda -> soda
# kosher salt -> salt
# all-purpose flour -> all purpose flour
# mini semi-sweet chocolate chips -> chocolate chip
# small yellow-fleshed potatoes -> yellow potato
# olive oil -> olive oil
# balsamic vinegar -> vinegar
# butter at room temperature -> butter room temperature
# garlic, minced -> garlic
# dried rosemary -> rosemary
# dried sage -> sage
# ground thyme -> ground thyme
# dried savory -> savory
# sea salt -> sea salt
# ground black pepper -> ground black pepper
# puffed wheat cereal -> wheat cereal
# unsalted butter -> butter
# packed brown sugar -> sugar
# corn syrup -> corn syrup
# cocoa powder -> cocoa powder
# vanilla extract -> vanilla extract
# flour, or more as needed, for dusting -> flour
# lemon cake mix -> lemon cake mix
# instant lemon pudding mix -> lemon pudding mix
# white sugar -> sugar
# eggs -> egg
# peach nectar -> peach nectar
# vegetable oil -> vegetable oil
# sifted confectioners' sugar -> confectioner sugar
# peach nectar -> peach nectar
# lemon juice -> lemon juice
# grated lemon peel -> lemon peel
# frozen sliced strawberries -> strawberry
# sugar -> sugar
# heavy cream -> cream
# bulk pork sausage -> pork sausage
# coleslaw mix -> coleslaw mix
# soy sauce -> soy sauce
# toasted sesame oil -> sesame oil
# grated ginger -> ginger
# garlic, minced -> garlic
# lemon zest -> lemon
# chopped fresh cilantro -> cilantro
# cream cheese, softened -> cream cheese
# minced clams, drained with juice reserved -> clam juice
# lemon juice -> lemon juice
# Worcestershire sauce -> worcestershire sauce
# onion juice -> onion juice
# minced garlic -> garlic
# whole almonds -> almond
# white sugar -> sugar
# kosher salt -> salt
# honey -> honey
# water -> water
# almond oil -> almond oil
# skinless boneless chicken thighs, cut in 1-inch pieces -> skinless boneless chicken thigh piece
# cornstarch, divided -> cornstarch
# olive oil, divided -> olive oil
# minced onion -> onion
# garlic, minced -> garlic
#  grated fresh ginger -> ginger
# reduced-sodium soy sauce -> sodium sauce soy sauce
# reduced sodium chicken broth -> reduced sodium chicken broth
# bourbon (or apple juice) -> bourbon apple juice
# packed brown sugar -> sugar
# cider vinegar -> cider vinegar
# crushed red pepper -> red pepper
# cooked rice -> rice
# green onions, sliced -> green onion
# baby potatoes, cut into quarters -> baby potato quarter
# avocado oil -> avocado oil
# granulated garlic -> garlic
# dried parsley -> parsley
# salt -> salt
# extra-firm tofu -> tofu
# toasted sesame oil -> sesame oil
# mayonnaise -> mayonnaise
# sweet chili sauce -> sweet sauce chili sauce
# Sriracha sauce -> sriracha sauce
# panko bread crumbs -> bread crumb
# green onion, chopped -> green onion
# egg -> egg
# white vinegar -> vinegar
# vegetable oil, or more as needed -> vegetable oil
# duck legs -> duck leg
# all-purpose flour -> all purpose flour
# all-purpose flour -> all purpose flour
# chicken broth -> chicken broth
# andouille sausage, thickly sliced -> andouille sausage
# onion, chopped -> onion
# diced serrano and pasilla peppers -> serrano pasilla pepper
# chopped celery -> celery
# green onions, chopped (Optional) -> green onion
# ground black pepper -> ground black pepper
# dried thyme -> thyme
# cayenne pepper, or to taste -> cayenne pepper
# bay leaf -> bay leaf
# diced fresh tomatoes -> tomato
# smoked ham hock -> ham hock
# water, or as needed -> water
# pickled okra, rinsed and sliced -> okra
# Gulf shrimp -> Gulf shrimp
# crawfish tail meat -> tail meat
# thinly sliced green onions (Optional) -> green onion
# olive oil -> olive oil
# beef stew meat -> meat
# onion, sliced -> onion
# taco seasoning mix (such as Savory Spice) -> taco seasoning mix Savory Spice
# water, divided -> water
# garlic salt -> salt
# yellow rice (such as Vigo) -> yellow rice Vigo
# black beans, drained, or to taste -> black bean
# corn kernels, drained, or to taste -> corn kernel
# shredded Cheddar cheese, or to taste -> Cheddar cheese
# ground beef -> ground beef
# onion, chopped -> onion
# diced tomatoes -> tomato
# whole kernel corn, drained -> kernel corn
# water -> water
# pinto beans, rinsed and drained -> pinto bean
# black beans, rinsed and drained -> black bean
# diced tomatoes and green chiles (such as RO*TEL) -> tomato green chile ro*tel
# tomato sauce -> tomato sauce
# taco seasoning -> taco seasoning
# dry ranch dressing mix (such as Hidden Valley Ranch) -> ranch dressing mix Hidden Valley Ranch
# black-eyed peas, rinsed and drained -> black pea
# red bell pepper, finely chopped -> red bell pepper
# yellow bell pepper, finely chopped -> yellow bell pepper
# onion, finely chopped -> onion
# jalapeño chiles, seeded and finely chopped -> jalapeño chile
# chopped fresh parsley -> parsley
# garlic, minced -> garlic
# red wine vinegar -> red wine vinegar
# balsamic vinegar -> vinegar
# olive oil -> olive oil
# salt -> salt
# ground black pepper -> ground black pepper
# ground cumin -> ground cumin
# cooked bacon, crumbled -> bacon
# chicken broth -> chicken broth
# green onions, sliced -> green onion
# chopped bok choy -> bok choy
# carrot, cut into 1/4-inch dice -> carrot dice
# celery, cut into 1/4-inch dice -> celery dice
# soy sauce -> soy sauce
# ginger root, peeled and minced -> ginger root
# creamy peanut butter -> peanut butter
# sriracha sauce -> sriracha sauce
# garlic, minced -> garlic
# white sugar -> sugar
# ramen noodles -> raman
# chopped cooked chicken  -> chicken
# russet potatoes, cut into 1-inch pieces -> russet potato piece
# chickpeas, rinsed and drained -> chickpea
# butternut squash - peeled, seeded, and cut into 1-inch pieces -> butternut squash piece
# sweet potato, peeled and cut into 1-inch cubes -> potato cube
# onion, diced -> onion
# carrots, cut into 1 inch pieces -> carrot piece
# vegetable oil -> vegetable oil
# salt -> salt
# onion powder -> onion powder
# garlic powder -> garlic powder
# ground fennel seeds -> ground fennel seed
# dried rubbed sage -> sage
# ground black pepper -> ground black pepper
# green onions, chopped (Optional) -> green onion
# packed brown sugar -> sugar
# unsalted butter, cut into small pieces -> butter piece
# bananas, sliced 1/4-inch thick -> banana
# all-purpose flour -> all purpose flour
# baking powder -> powder
# baking soda -> soda
# ground cinnamon -> ground cinnamon
# salt -> salt
# white sugar -> sugar
# unsalted butter, softened -> butter
# eggs -> egg
# vanilla extract -> vanilla extract
# overripe bananas, mashed -> overripe banana
# sour cream -> cream
# pineapple juice -> pineapple juice
# coconut oil -> coconut oil
# vanilla extract -> vanilla extract
# ground cinnamon -> ground cinnamon
# sea salt -> sea salt
# rolled oats -> oat
# sunflower seeds -> sunflower seed
# pitted dates -> date
# roasted almonds -> almond
# quick-cooking oats -> cooking oat
# raisins -> raisin
# dried cranberries -> cranberry
# chicken broth -> chicken broth
# chicken chunks, drained -> chicken chunk
# white rice -> white rice
# cream of chicken soup -> cream chicken soup
# lemon juice, or to taste -> lemon juice
# almond milk -> almond milk
# chia seeds, or more to taste -> chia seed
# fresh blueberries -> blueberry
# maple syrup, or more to taste -> maple syrup
# vanilla extract -> vanilla extract
# ground cinnamon -> ground cinnamon
# all-purpose flour -> all purpose flour
# white sugar -> sugar
# buttermilk -> buttermilk
# eggs -> egg
# vegetable oil -> vegetable oil
# vanilla extract -> vanilla extract
# baking powder -> powder
# ground cinnamon -> ground cinnamon
# salt -> salt
# baking soda -> soda
# white sugar -> sugar
# butter or margarine -> butter margarine
# ground cinnamon -> ground cinnamon
# white bread, cut into 1 inch cubes -> bread cube
# shredded Cheddar cheese -> Cheddar cheese
# chopped fresh mushrooms (Optional) -> mushroom
# crumbled cooked bacon -> bacon
# eggs -> egg
# half-and-half -> half half
# Dijon mustard -> Dijon mustard
# ground beef -> ground beef
# ground turkey -> ground turkey
# ground Italian sausage -> sausage
# onion, diced -> onion
# eggs -> egg
# Italian-style seasoned bread crumbs -> style bread crumb
# quick cooking oats -> cooking oat
# Italian-style seasoning -> style seasoning
# vegetable oil, or as needed -> vegetable oil
# large marshmallows -> marshmallow
# butter -> butter
# brown sugar -> sugar
# popped popcorn ->
# pecans -> pecan
# panko bread crumbs -> bread crumb
# cornstarch -> cornstarch
# thick-cut pork chops -> thick cut pork chop
# Italian seasoning -> seasoning
# garlic salt -> salt
# ground black pepper -> ground black pepper
# Dijon mustard -> Dijon mustard
# honey -> honey
# unsalted butter -> butter
# canola oil -> canola oil
# chopped mixed dried fruit  -> fruit
# golden raisins -> golden raisin
# water -> water
# margarine -> margarine
# white sugar -> sugar
# mixed spice -> spice
# cinnamon -> cinnamon
# all-purpose flour -> all purpose flour
# eggs, beaten -> egg
# baking soda -> soda
# olive oil -> olive oil
# beef top sirloin steaks -> beef sirloin
# salt and freshly ground black pepper to taste -> salt black pepper
# cayenne pepper, or to taste -> cayenne pepper
# diced onions -> onion
# mini sandwich rolls -> sandwich roll
# freshly shredded provolone cheese -> cheese
# chopped pickled peppers -> pepper
# cream cheese, softened -> cream cheese
# kosher salt -> salt
# freshly ground black pepper -> black pepper
# vegetable oil -> vegetable oil
# venison stew meat -> venison meat
# beef-flavored rice mix -> beef rice mix
# butter -> butter
# water -> water
# green bell pepper, seeded and sliced into strips -> green bell pepper strip
# red bell pepper, seeded and sliced into strips -> red bell pepper strip
# onion, chopped -> onion
# cornstarch -> cornstarch
# paprika -> paprika
# coarsely ground black pepper -> black pepper
# lean veal stew meat -> veal meat
# extra-virgin olive oil -> extra oil virgin oil olive oil
# onion, minced -> onion
# carrot, minced -> carrot
# celery, minced -> celery
# fresh Thai chile pepper, minced -> Thai chile pepper
# garlic, crushed -> garlic
# low-sodium vegetable broth -> low sodium vegetable broth
# dry white wine -> wine
# Yukon Gold potatoes, peeled and cut into 1-inch cubes -> Yukon Gold potato cube
# Roma tomatoes, cubed -> Roma tomato
# frozen peas -> pea
# bay leaf -> bay leaf
# water, or as needed -> water
# Italian sausage -> sausage
# diced onion -> onion
# chicken broth -> chicken broth
# diced tomatoes with basil, garlic, and oregano -> tomato basil garlic oregano
# farfalle pasta -> farfalle pasta
# Italian seasoning -> seasoning
# salt, or to taste -> salt
# ground black pepper, or to taste -> ground black pepper
# ricotta cheese -> ricotta cheese
# shredded mozzarella cheese -> mozzarella cheese
# freshly grated Parmesan cheese -> Parmesan cheese
# chopped fresh basil -> basil
# confectioners' sugar, sifted -> confectioner sugar
# cream cheese, softened -> cream cheese
# vanilla extract, divided -> vanilla extract
# milk, or as needed -> milk
# all-purpose flour -> all purpose flour
# white sugar -> sugar
# unsweetened cocoa powder -> unsweetene powder cocoa powder
# baking powder -> powder
# salt -> salt
# eggs -> egg
# buttermilk -> buttermilk
# milk -> milk
# red food coloring -> red food coloring
# distilled white vinegar -> vinegar
# melted butter -> butter
# cooking spray -> cooking spray
# white sugar -> sugar
# butter, softened -> butter
# eggs -> egg
# baking soda -> soda
# water -> water
# seedless blackberry jam -> blackberry jam
# all-purpose flour -> all purpose flour
# ground cinnamon -> ground cinnamon
# ground nutmeg -> ground nutmeg
# ground cloves -> ground
# salt -> salt
# buttermilk -> buttermilk
# chopped black walnuts (Optional) -> black walnut
# golden raisins (Optional) -> golden raisin
# diced tomatoes -> tomato
# chicken broth -> chicken broth
# Great Northern beans, undrained -> bean
# water -> water
# chopped spinach, drained -> spinach
# tomato sauce -> tomato sauce
# crisp cooked bacon, crumbled -> bacon
# minced garlic -> garlic
# dried parsley -> parsley
# salt -> salt
# garlic powder -> garlic powder
# ground black pepper -> ground black pepper
# dried basil -> basil
# seashell pasta -> pasta
# grated Romano cheese, or as needed -> Romano cheese
# all-purpose flour -> all purpose flour
# whole wheat flour -> whole flour wheat flour
# rolled oats -> oat
# salt -> salt
# baking soda -> soda
# baking powder -> powder
# cold unsalted butter, cut into small cubes -> butter cube
# buttermilk -> buttermilk
# egg -> egg
# honey, or more to taste -> honey
# grated orange zest -> orange
# dried currants -> currant
# golden raisins -> golden raisin
# potatoes, peeled and quartered -> potato
# chicken bouillon cubes -> chicken bouillon cube
# warm milk -> warm milk
# melted butter -> butter
# cooking oil -> cook oil
# pork sausage -> pork sausage
# onion, sliced and separated into rings -> onion ring
# homestyle beef gravy -> homestyle beef gravy
# crumbled dried oregano -> oregano
# skinless, boneless chicken breast halves -> skinless boneless chicken breast half
# water -> water
# condensed cream of mushroom soup -> cream mushroom soup
# onion, chopped -> onion
# chopped celery -> celery
# chopped carrots -> carrot
# baby bell peppers, chopped -> baby bell pepper
# dry onion soup mix (such as Lipton) -> onion soup mix Lipton
# dry black beans, soaked overnight -> black bean
# chicken broth -> chicken broth
# diced jalapeño peppers -> jalapeño pepper
# chili powder -> chili powder
# ground cumin -> ground cumin
# cayenne pepper -> cayenne pepper
# ground black pepper -> ground black pepper
# garlic powder -> garlic powder
# hot pepper sauce -> hot sauce pepper sauce
# canola oil, divided -> canola oil
# bison meat, cut into 1-inch cubes -> bison meat cube
# minced yellow onion -> yellow onion
# minced celery -> celery
# garlic, minced -> garlic
# flour -> flour
# low-sodium chicken broth -> low sodium chicken broth
# tomato sauce -> tomato sauce
# water -> water
# white wine -> wine
# chopped fresh parsley -> parsley
# salt (Optional) -> salt
# ground black pepper -> ground black pepper
# whole cloves ->
# ground thyme -> ground thyme
# skinless, boneless chicken breast halves -> skinless boneless chicken breast half
# ranch dressing -> ranch dressing
# sour cream -> cream
# hot sauce -> hot sauce
# shredded Cheddar cheese, divided -> Cheddar cheese
# frozen cauliflower rice -> cauliflower rice
# eggs -> egg
# nopales (fresh cactus leaves) -> nopale cactus
# chopped green onions -> green onion
# soy sauce -> soy sauce
# ground beef -> ground beef
# beef stock -> beef stock
# beef broth -> beef broth
# Italian-style diced tomatoes -> style tomato
# spaghetti sauce -> spaghetti sauce
# red kidney beans, drained -> red kidney bean
# white kidney beans, drained -> white kidney bean
# celery, diced -> celery
# carrots, diced -> carrot
# chopped onion -> onion
# chopped fresh parsley -> parsley
# dried oregano -> oregano
# ground black pepper -> ground black pepper
# salt -> salt
# hot pepper sauce (such as Tabasco) -> hot sauce pepper sauce Tabasco
# ditalini pasta -> pasta
# soy sauce -> soy sauce
# sherry -> sherry
# rice wine vinegar -> rice wine vinegar
# oyster sauce -> oyster sauce
# chopped scallions -> scallion
# white sugar -> sugar
# lemon juice -> lemon juice
# ginger stir-in paste -> ginger stir paste
# cornstarch -> cornstarch
# all-purpose flour -> all purpose flour
# club soda -> club soda
# egg, beaten -> egg
# large shrimp - peeled, deveined, and tails left on -> shrimp tail
# carrots, unpeeled, halved -> carrot
# onion, halved -> onion
# celery, halved -> celery
# garlic, halved -> garlic
# whole black peppercorns -> black peppercorn
# salt -> salt
# fresh thyme -> thyme
# fresh rosemary -> rosemary
# water -> water
# half-and-half -> half half
# white sugar -> sugar
# brown sugar -> sugar
# heavy whipping cream -> whipping cream
# vanilla extract -> vanilla extract
# Irish cream liqueur -> cream liqueur
# vegetable broth -> vegetable broth
# 15-bean soup mix (seasoning packet not used) -> bean soup mix seasoning packet
# diced Italian-style tomatoes -> style tomato
# onion, diced -> onion
# carrots, diced -> carrot
# celery, chopped -> celery
# garlic, minced -> garlic
# sea salt -> sea salt
# smoked paprika -> paprika
# ground black pepper -> ground black pepper
# bacon, or more to taste -> bacon
# onion, chopped -> onion
# garlic, minced -> garlic
# chicken broth -> chicken broth
# dry black-eyed peas -> black pea
# salt -> salt
# ground black pepper -> ground black pepper
# warm water (100 to 110 degrees F/40 to 45 degrees C) -> water degree degree
# bread flour -> bread flour
# active dry yeast -> yeast
# white sugar -> sugar
# bread flour -> bread flour
# quick-cooking oats -> cooking oat
# whole wheat flour -> whole flour wheat flour
# brown sugar -> sugar
# vegetable oil -> vegetable oil
# salt -> salt
# potatoes, peeled and cubed -> potato
# cream cheese -> cream cheese
# sour cream -> cream
# butter, cut into pieces -> butter piece
# salt -> salt
# chopped fresh chives -> chive
# paprika, or more to taste -> paprika
# brown rice syrup -> rice syrup
# coconut oil -> coconut oil
# natural peanut butter -> peanut butter
# vanilla extract -> vanilla extract
# regular or quick-cooking oats, or more to taste -> cooking oat
# raisins -> raisin
# unsweetened flaked coconut -> coconut
# fresh blueberries, divided -> blueberry
# white sugar -> sugar
# water -> water
# cornstarch -> cornstarch
# ground cinnamon -> ground cinnamon
# cold butter, cut into pieces -> butter piece
# unsweetened chocolate -> chocolate
# butter -> butter
# all-purpose flour -> all purpose flour
# baking soda -> soda
# baking powder -> powder
# salt -> salt
# white sugar -> sugar
# eggs -> egg
# vanilla extract -> vanilla extract
# sour cream -> cream
# semisweet chocolate chips -> semisweet chocolate chip
# mayonnaise -> mayonnaise
# white sugar -> sugar
# seasoned rice wine vinegar -> rice wine vinegar
# lemon juice -> lemon juice
# prepared horseradish -> horseradish
# onion powder -> onion powder
# dry mustard -> mustard
# celery salt -> celery salt
# salt -> salt
# ground black pepper -> ground black pepper
# coleslaw mix -> coleslaw mix
# whole chicken, cut into parts -> chicken part
# melted butter -> butter
# crushed saltine crackers -> saltine cracker
# cooking spray -> cooking spray
# boneless skinless chicken breasts, cut into chunks -> boneless skinless chicken breast chunk
# frozen broccoli florets -> broccoli floret
# condensed cream of mushroom soup -> cream mushroom soup
# water -> water
# instant white rice, uncooked -> rice
# Kraft Shredded Three Cheese with a Touch of Philadelphia -> Kraft Shredded Three Cheese Touch Philadelphia
# ground turkey -> ground turkey
# crushed cheese-flavored crackers -> cheese cracker
# egg -> egg
# red pepper flakes -> red pepper flake
# garlic powder -> garlic powder
# dried minced onion (Optional) -> onion
# diced potatoes, drained -> potato
# green beans, drained -> green bean
# shredded Colby cheese -> Colby cheese
# condensed cream of chicken soup -> cream chicken soup
# cold water -> water
# cornstarch -> cornstarch
# honey -> honey
# thinly sliced green onions -> green onion
# lemon juice -> lemon juice
# prepared Dijon-style mustard -> Dijon style mustard
# onion powder -> onion powder
# boiling water -> boiling water
# rolled oats -> oat
# packed brown sugar -> sugar
# white sugar -> sugar
# unsalted butter, softened -> butter
# eggs -> egg
# all-purpose flour -> all purpose flour
# baking soda -> soda
# ground cinnamon -> ground cinnamon
# ground nutmeg -> ground nutmeg
# salt -> salt
# flaked coconut -> coconut
# white sugar -> sugar
# packed brown sugar -> sugar
# unsalted butter, melted -> butter
# vanilla extract -> vanilla extract
# cream -> cream
# boiling water -> boiling water
# quick-cooking oats -> cooking oat
# butter -> butter
# packed brown sugar -> sugar
# white sugar -> sugar
# eggs -> egg
# vanilla extract -> vanilla extract
# baking soda -> soda
# salt -> salt
# ground cinnamon -> ground cinnamon
# all-purpose flour -> all purpose flour
# raisins -> raisin
# crushed tomatoes -> tomato
# water, divided -> water
# white sugar -> sugar
# distilled white vinegar -> vinegar
# onion powder -> onion powder
# garlic powder -> garlic powder
# salt -> salt
# celery salt -> celery salt
# mustard powder -> mustard powder
# finely ground black pepper  -> black pepper
# cayenne pepper, or to taste -> cayenne pepper
# whole clove -> clove
# soy sauce -> soy sauce
# seasoned rice vinegar -> rice vinegar
# finely chopped Chinese chives -> chive
# sesame seeds -> sesame seed
# chile-garlic sauce (such as Sriracha) -> chile garlic sauce Sriracha
# ground pork -> ground pork
# garlic, minced -> garlic
# egg, beaten -> egg
# finely chopped Chinese chives -> chive
# soy sauce -> soy sauce
# sesame oil -> sesame oil
# minced fresh ginger -> ginger
# dumpling wrappers -> wrapper
# vegetable oil for frying, or as needed -> vegetable oil frying
# rotisserie chicken -> rotisserie chicken
# butter -> butter
# onion, diced -> onion
# celery, sliced thin -> celery
# all-purpose flour -> all purpose flour
# chicken broth -> chicken broth
# new potatoes, cut into 1/2-inch dice -> potato dice
# frozen mixed vegetables -> vegetable
# salt -> salt
# ground black pepper -> ground black pepper
# dried basil -> basil
# dried thyme -> thyme
# all-purpose flour -> all purpose flour
# baking powder -> powder
# salt -> salt
# cold butter, cubed -> butter
# milk, or more as needed -> milk
# dried dill -> dill
# buckwheat flakes -> flake
# packed brown sugar -> sugar
# unsalted butter, softened -> butter
# vanilla extract -> vanilla extract
# buckwheat flour -> buckwheat flour
# gluten-free all-purpose baking flour -> all purpose bake flour
# rice flour -> rice flour
# baking powder -> powder
# packed brown sugar -> sugar
# unsalted butter, softened -> butter
# eggs -> egg
# ripe bananas, cut into chunks -> banana chunk
# chopped walnuts -> walnut
# all-purpose flour, plus -> all purpose flour
# all-purpose flour -> all purpose flour
# salt -> salt
# butter -> butter
# water -> water
# eggs -> egg
# white sugar -> sugar
# buttermilk -> buttermilk
# baking soda -> soda
# baking powder -> powder
# vanilla extract -> vanilla extract
# almond extract (Optional) -> almond extract
# butter -> butter
# milk -> milk
# confectioners' sugar, sifted -> confectioner sugar
# chopped pecans -> pecan
# almond or vanilla extract -> almond vanilla extract
# all-purpose flour -> all purpose flour
# self-rising flour -> self rise flour
# butter -> butter
# egg, beaten -> egg
# cold water -> water
# salt -> salt
# fresh pineapple - peeled, cored and shredded -> pineapple
# white sugar -> sugar
# whole cloves ->
# egg, beaten -> egg
# cooking spray or oil for greasing -> spray oil
# all purpose flour, for dusting pan -> all purpose flour pan
# unsalted pistachios, toasted or 1/3 cup pistachio butter -> pistachio cup pistachio butter
# white cake mix -> white cake mix
# instant pistachio pudding mix -> pistachio pudding mix
# water -> water
# eggs -> egg
# vegetable oil -> vegetable oil
# green food coloring -> green food coloring
# pistachio extract (Optional) -> pistachio
# confectioners sugar -> confectioner
# heavy cream -> cream
# vanilla extract -> vanilla extract
# chopped pistachios for garnish (Optional) -> pistachio
# unsalted butter -> butter
# white and cremini mushrooms, cut into quarters -> cremini mushroom quarter
# bok choy, chopped -> bok choy
# green onions, sliced -> green onion
# minced garlic, or more to taste -> garlic
# fresh ginger, quartered -> ginger
# lime juice -> lime juice
# chicken broth -> chicken broth
# chopped fresh cilantro -> cilantro
# all-purpose flour -> all purpose flour
# baking powder -> powder
# salt -> salt
# shortening or butter -> shortening
# milk -> milk
# white vinegar -> vinegar
# fish sauce -> fish sauce
# white sugar -> sugar
# lime juice -> lime juice
# garlic, minced -> garlic
# red pepper flakes -> red pepper flake
# canola oil -> canola oil
# chopped shallots -> shallot
# skewers -> skewer
# medium shrimp, with shells -> shrimp shell
# rice vermicelli noodles -> rice vermicelli noodle
# finely chopped lettuce -> lettuce
# bean sprouts -> bean sprout
# English cucumber, cut into 2-inch matchsticks -> cucumber matchstick
# finely chopped pickled carrots -> carrot
# finely chopped diakon radish -> diakon radish
# crushed peanuts -> peanut
# chopped cilantro -> cilantro
# finely chopped Thai basil -> Thai basil
# chopped fresh mint -> mint
# whole chicken -> chicken
# all-purpose flour -> all purpose flour
# baking powder -> powder
# hot chicken broth -> hot chicken broth
# egg -> egg
# cooking spray -> cooking spray
# all-purpose flour -> all purpose flour
# baking soda -> soda
# baking powder -> powder
# ground cinnamon -> ground cinnamon
# salt -> salt
# very ripe bananas -> banana
# caramel macchiato-flavored liquid coffee creamer (such as International Delight) -> caramel macchiato coffee creamer International Delight
# white sugar -> sugar
# vegetable oil -> vegetable oil
# eggs -> egg
# instant coffee granules -> coffee granule
# unsalted butter -> butter
# packed brown sugar -> sugar
# vanilla extract -> vanilla extract
# vegetable oil -> vegetable oil
# ground beef -> ground beef
# onion, chopped -> onion
# shredded cabbage -> cabbage
# red kidney beans, drained -> red kidney bean
# tomato sauce -> tomato sauce
# water -> water
# beef bouillon cubes -> beef bouillon cube
# ground cumin -> ground cumin
# salt -> salt
# pepper -> pepper
# creamy peanut butter -> peanut butter
# whole wheat bread -> wheat bread
# dill pickle -> dill pickle
# finely chopped onion -> onion
# mayonnaise -> mayonnaise
# cubed lean venison -> venison
# all-purpose flour -> all purpose flour
# canola oil -> canola oil
# sliced mushrooms -> mushroom
# onion, diced -> onion
# tomato sauce -> tomato sauce
# Worcestershire sauce -> worcestershire sauce
# salt -> salt
# pepper -> pepper
# garlic powder -> garlic powder
# sour cream -> cream
# butter -> butter
# onion, minced -> onion
# celery, chopped -> celery
# all-purpose flour -> all purpose flour
# chicken stock -> chicken stock
# Brie cheese with the rind, cubed -> Brie cheese rind
# heavy cream -> cream
# green bell pepper, cut into very fine matchsticks -> green bell pepper matchstick
# red bell pepper, cut into very fine matchsticks -> red bell pepper matchstick
# frozen blackberries -> blackberry
# white sugar -> sugar
# cornstarch -> cornstarch
# water -> water
# lemon juice -> lemon juice
# vanilla extract -> vanilla extract
# quick-cooking oats -> cooking oat
# all-purpose flour -> all purpose flour
# packed brown sugar -> sugar
# ground cinnamon -> ground cinnamon
# cold unsalted butter, cut into pieces -> butter piece
# semisweet chocolate, chopped -> semisweet chocolate
# unsalted butter -> butter
# large eggs, at room temperature  -> egg room temperature
# white sugar -> sugar
# all-purpose flour -> all purpose flour
# cayenne pepper -> cayenne pepper
# salt -> salt
# russet potatoes, scrubbed -> russet potato
# olive oil, or as needed -> olive oil
# salt -> salt
# ground black pepper -> ground black pepper
# onion powder -> onion powder
# wheat bran -> wheat bran
# dark brown sugar -> sugar
# whole milk -> whole milk
# all-purpose flour -> all purpose flour
# white sugar -> sugar
# baking powder -> powder
# salt -> salt
# ground cinnamon -> ground cinnamon
# grapeseed oil -> grapeseed oil
# eggs -> egg
# molasses -> molasse
# orange, zested -> orange
# fresh cranberries -> cranberry
# onions, chopped -> onion
# chicken broth -> chicken broth
# garlic, minced -> garlic
# butter -> butter
# all-purpose flour -> all purpose flour
# milk -> milk
# heavy cream -> cream
# tomato paste -> tomato paste
# Worcestershire sauce -> worcestershire sauce
# seafood seasoning (such as Old Bay) -> seafood seasoning Old Bay
# salt -> salt
# cayenne pepper -> cayenne pepper
# imitation lobster meat -> imitation lobster meat
# white wine -> wine
# ground paprika, or to taste (Optional) -> ground paprika
# broccoli, cut into florets -> broccoli floret
# panko bread crumbs -> bread crumb
# olive oil -> olive oil
# garlic powder -> garlic powder
# lemon zest -> lemon
# kosher salt -> salt
# ground black pepper -> ground black pepper
# red pepper flakes (Optional) -> red pepper flake
# lemon juice -> lemon juice
# grated Parmesan cheese -> Parmesan cheese
# skinless, boneless chicken thighs -> skinless boneless chicken thigh
# water -> water
# chicken stock -> chicken stock
# olive oil -> olive oil
# onion, thinly sliced -> onion
# garlic, chopped -> garlic
# potatoes, cubed -> potato
# garbanzo beans, drained -> garbanzo bean
# fresh spinach -> spinach
# diced roasted red peppers (Optional) -> red pepper
# salt and pepper to taste -> salt pepper
# grated Parmesan cheese -> Parmesan cheese
# olive oil -> olive oil
# mushroom stems and pieces, drained -> mushroom piece
# onion, coarsely chopped -> onion
# vegetable broth -> vegetable broth
# soy sauce -> soy sauce
# oyster sauce -> oyster sauce
# baby carrots -> baby carrot
# small yellow potatoes (such as Dutch Yellow Pee Wee potatoes) -> yellow potato Dutch Yellow Pee Wee potato
# sweet onion, cut into bite-sized pieces -> onion bite piece
# water -> water
# corned beef brisket with spice packet -> beef brisket spice packet
# onion powder -> onion powder
# garlic powder -> garlic powder
# Irish stout beer (such as Guinness) -> beer Guinness
# cabbage, quartered and leaves separated -> cabbage leave
# potatoes, peeled and cubed -> potato
# celery, diced -> celery
# onion, diced -> onion
# water -> water
# beef base (such as Better than Bouillon) -> beef base Bouillon
# leftover cooked beef, cubed -> leftover beef
# frozen peas and carrots -> pea carrot
# parsley flakes -> parsley flake
# dried oregano -> oregano
# dried basil -> basil
# bacon -> bacon
# butter or margarine -> butter margarine
# eggs -> egg
# tomatoes, sliced -> tomato
# whole mushrooms -> mushroom
# prepared soda bread -> soda bread
# eggs, separated, divided -> egg
# all-purpose flour -> all purpose flour
# raisins (Optional) -> raisin
# milk -> milk
# white sugar -> sugar
# salt -> salt
# butter -> butter
# confectioners' sugar -> confectioner sugar
# applesauce (Optional) -> applesauce
# dry pinto beans -> pinto bean
# diced yellow onion -> yellow onion
# garlic, chopped -> garlic
# chili powder -> chili powder
# ground cumin -> ground cumin
# celery seed -> celery seed
# salt -> salt
# ground black pepper -> ground black pepper
# fire-roasted diced tomatoes -> fire tomato
# hot pepper sauce (such as Tapatio) -> hot sauce pepper sauce Tapatio
# dried Mexican oregano -> Mexican oregano
# cayenne pepper -> cayenne pepper
# frozen lobster tails, partially thawed -> lobster tail
# olive oil -> olive oil
# lemon-pepper seasoning -> lemon pepper seasoning
# buttermilk -> buttermilk
# hot pepper sauce -> hot sauce pepper sauce
# salt -> salt
# bone-in chicken pieces, with skin -> bone chicken piece skin
# all-purpose flour -> all purpose flour
# sweet paprika -> paprika
# smoked paprika -> paprika
# garlic salt -> salt
# onion powder -> onion powder
# salt -> salt
# ground black pepper -> ground black pepper
# ground cumin -> ground cumin
# dried thyme -> thyme
# dried basil -> basil
# dried oregano -> oregano
# cooking spray -> cooking spray
# vegetable oil -> vegetable oil
# chicken breasts, cut into 1/2-inch cubes -> chicken breast cube
# onion, diced -> onion
# garlic, crushed -> garlic
# green enchilada sauce -> green sauce enchilada sauce
# dry great northern beans, sorted and rinsed -> bean
# chicken broth -> chicken broth
# chopped green chiles (such as Hatch), undrained -> green chile Hatch
# oregano -> oregano
# cumin -> cumin
# shredded Cheddar-Monterey Jack cheese blend, or to taste -> Cheddar Monterey Jack cheese blend
# chopped cilantro, or to taste -> cilantro
# all-purpose flour -> all purpose flour
# vegetable oil -> vegetable oil
# butter -> butter
# chopped celery -> celery
# chopped green onions -> green onion
# green bell pepper, chopped -> green bell pepper
# water -> water
# tomato sauce -> tomato sauce
# Worcestershire sauce -> worcestershire sauce
# garlic, minced -> garlic
# salt, divided, or to taste -> salt
# hot pepper sauce (such as Tabasco), or to taste -> hot sauce pepper sauce Tabasco
# dried thyme -> thyme
# frozen chopped okra -> okra
# catfish, cut into 2-inch pieces -> catfish piece
# peeled and deveined shrimp -> shrimp
# gumbo file powder, or to taste -> gumbo powder file powder
# ube (purple yam), peeled and cut into 1/4-inch-thick fries -> yam fry
# olive oil -> olive oil
# Sriracha-flavored salt -> Sriracha salt
# sour cream -> cream
# Sriracha sauce, or more to taste -> sriracha sauce
# vegetable oil -> vegetable oil
# skinless, boneless chicken breast halves, cut into cubes -> skinless boneless chicken breast half cube
# onion, chopped -> onion
# green bell pepper, chopped -> green bell pepper
# chili powder -> chili powder
# ground cumin -> ground cumin
# white kidney beans (cannellini), rinsed and drained -> white kidney bean cannellini
# frozen whole kernel corn -> kernel corn
# Campbell's condensed cream of chicken soup -> Campbell cream chicken soup
# water -> water
# shredded Cheddar cheese -> Cheddar cheese
# white sugar -> sugar
# lite soy sauce -> lite sauce soy sauce
# oyster sauce -> oyster sauce
# low-sodium canned luncheon meat (such as Spam), cut into 1/2-inch cubes -> low sodium canned luncheon meat Spam cube
# water -> water
# medium-grain white rice (such as Calrose) -> grain rice Calrose
# rice vinegar -> rice vinegar
# roasted and seasoned seaweed, torn into 1 1/2-inch pieces -> seaweed piece
# butter, divided, or more as needed -> butter
# sliced fresh mushrooms -> mushroom
# skinless, boneless chicken breast halves -> skinless boneless chicken breast half
# all-purpose flour -> all purpose flour
# Marsala wine -> Marsala wine
# low-sodium chicken broth -> low sodium chicken broth
# salt -> salt
# ground black pepper -> ground black pepper
# shredded mozzarella cheese -> mozzarella cheese
# grated Parmesan cheese -> Parmesan cheese
# green onions, chopped -> green onion
# poppy seeds -> seed
# sesame seeds -> sesame seed
# dried onion flakes -> onion flake
# kosher salt -> salt
# lean ground beef -> ground beef
# onion, diced -> onion
# bell pepper, minced -> bell pepper
# pinto beans -> pinto bean
# diced tomatoes -> tomato
# tomato sauce -> tomato sauce
# chili powder -> chili powder
# jalapeño peppers, minced (Optional) -> jalapeño pepper
# crushed red pepper flakes -> red pepper flake
# ground black pepper -> ground black pepper
# salt -> salt
# garlic powder -> garlic powder
# baby red potatoes, cut into 1½-inch wedges -> baby red potato wedge
# yellow onion, diced -> yellow onion
# bell pepper, diced -> bell pepper
# olive oil -> olive oil
# garlic powder -> garlic powder
# salt, or to taste -> salt
# ground black pepper, or to taste -> ground black pepper
# acai berry sorbet -> acai berry sorbet
# granola, or as desired -> granola
# strawberries, sliced -> strawberry
# banana, sliced -> banana
# unsweetened coconut flakes, or as desired -> coconut flake
# honey, or as desired -> honey
# milk -> milk
# butter -> butter
# all-purpose flour -> all purpose flour
# baking powder -> powder
# chopped fresh parsley -> parsley
# salt -> salt
# club soda -> club soda
# chicken stock -> chicken stock
# condensed cream of chicken soup -> cream chicken soup
# skinless, boneless chicken breast halves -> skinless boneless chicken breast half
# potatoes, cubed -> potato
# yellow onion, diced -> yellow onion
# celery, diced -> celery
# diced carrot -> carrot
# green bell pepper, seeded and chopped -> green bell pepper
# frozen peas, thawed (Optional) -> pea
# lemon, thinly sliced (Optional) -> lemon
# fresh thyme -> thyme
# heavy cream -> cream
# salt and ground black pepper to taste -> salt ground black pepper
# butter -> butter
# chopped morel mushrooms -> morel mushroom
# chopped fresh parsley, or to taste -> parsley
# chopped green onion, or to taste -> green onion
# all-purpose flour, or more if needed -> all purpose flour
# white sugar -> sugar
# rapid rise yeast -> rise yeast
# salt -> salt
# eggs at room temperature -> egg room temperature
# butter -> butter
# Bulgarian-style buttermilk -> style buttermilk
# cream cheese at room temperature -> cream cheese room temperature
# confectioners' sugar -> confectioner sugar
# all-purpose flour (Optional) -> all purpose flour
# lemon juice -> lemon juice
# vanilla extract -> vanilla extract
# ground nutmeg -> ground nutmeg
# egg -> egg
# water -> water
# confectioners' sugar -> confectioner sugar
# corn syrup -> corn syrup
# milk -> milk
# lemon juice, or as needed -> lemon juice
# cooking spray -> cooking spray
# yellow cake mix -> yellow cake mix
# instant vanilla pudding mix -> vanilla pudding mix
# chopped walnuts, divided -> walnut
# Irish whiskey, divided -> whiskey
# milk -> milk
# vegetable oil -> vegetable oil
# eggs -> egg
# butter -> butter
# brown sugar -> sugar
# water -> water
# round steak, cut into 1/2-inch cubes -> steak cube
# all-purpose flour -> all purpose flour
# lard -> lard
# bacon, finely chopped -> bacon
# onions, minced -> onion
# fresh mushrooms, sliced (Optional) -> mushroom
# Irish stout beer (such as Guinness) -> beer Guinness
# chopped fresh parsley -> parsley
# raisins (Optional) -> raisin
# brown sugar -> sugar
# double-crust pie pastry, thawed, divided -> crust pie pastry
# reduced-sodium soy sauce -> sodium sauce soy sauce
# rice vinegar -> rice vinegar
# finely grated ginger, or more to taste -> ginger
# garlic, minced -> garlic
# white sugar -> sugar
# toasted sesame oil -> sesame oil
# gochujang (Korean hot sauce) -> gochujang korean sauce hot sauce
# thinly sliced green onion -> green onion
# toasted sesame seeds -> sesame seed
# water -> water
# soy sauce -> soy sauce
# salt -> salt
# uncooked instant rice -> instant rice
# vegetable oil -> vegetable oil
# onion, finely chopped -> onion
# sliced green beans or peas -> green bean pea
# egg, lightly beaten -> egg
# ground black pepper -> ground black pepper
# egg noodles -> egg noodle
# canola oil -> canola oil
# dry-roasted peanuts -> peanut
# low-sodium soy sauce -> low sodium sauce soy sauce
# sambal oelek (chile paste) -> oelek chile paste
# white sugar -> sugar
# garlic, peeled -> garlic
# fresh ginger, peeled -> ginger
# ground pork -> ground pork
# salt -> salt
# cucumber - peeled, seeded, and chopped -> cucumber
# thinly sliced green onion -> green onion
# chopped fresh cilantro -> cilantro
# lime juice -> lime juice
# fresh pineapple, peeled and cut into cubes -> pineapple cube
# cucumbers -> cucumber
# lemon, peeled -> lemon
# artichoke hearts, drained -> heart
# grated Romano cheese -> Romano cheese
# grated Parmesan cheese -> Parmesan cheese
# minced garlic -> garlic
# frozen chopped spinach, thawed and drained -> spinach
# heavy cream -> cream
# sour cream -> cream
# shredded mozzarella cheese -> mozzarella cheese
# flat beer -> beer
# butter -> butter
# sugar -> sugar
# salt -> salt
# all-purpose flour -> all purpose flour
# yeast -> yeast
# olive oil, for brushing -> olive oil
# white sugar -> sugar
# butter -> butter
# eggs -> egg
# buttermilk -> buttermilk
# red food coloring -> red food coloring
# vanilla extract -> vanilla extract
# baking soda -> soda
# distilled white vinegar -> vinegar
# all-purpose flour -> all purpose flour
# unsweetened cocoa powder -> unsweetene powder cocoa powder
# salt -> salt
# cream cheese, softened -> cream cheese
# confectioners' sugar -> confectioner sugar
# vanilla extract -> vanilla extract
# fresh strawberries, hulled and cored -> strawberry
# graham crackers, crushed, or as needed -> graham crackers
# chicken broth -> chicken broth
# frozen O'Brien hash brown potatoes -> O'Brien potato
# diced tomatoes -> tomato
# frozen mixed vegetables (corn, peas, carrots, green beans, and lima beans) -> vegetable corn pea carrot green bean lima bean
# celery rib, sliced -> celery rib
# Worcestershire sauce -> worcestershire sauce
# smoked paprika -> paprika
# dried oregano -> oregano
# onion powder -> onion powder
# salt -> salt
# freeze-dried dill -> dill
# ground black pepper -> ground black pepper
# mayonnaise -> mayonnaise
# sweet chili sauce -> sweet sauce chili sauce
# Sriracha sauce -> sriracha sauce
# flour -> flour
# chicken breast tenderloins, cut into bite-sized pieces -> chicken breast tenderloin bite piece
# panko bread crumbs -> bread crumb
# green onions, chopped -> green onion
# white sugar -> sugar
# unsalted butter, melted -> butter
# unsweetened cocoa powder -> unsweetene powder cocoa powder
# red food coloring -> red food coloring
# vanilla extract -> vanilla extract
# distilled white vinegar -> vinegar
# salt -> salt
# large eggs, slightly beaten -> egg
# all-purpose flour -> all purpose flour
# cream cheese at room temperature -> cream cheese room temperature
# white sugar -> sugar
# egg -> egg
# vanilla extract -> vanilla extract
# Mexican-style corn -> style corn
# shredded Cheddar cheese -> Cheddar cheese
# sour cream -> cream
# mayonnaise -> mayonnaise
# diced green chiles, drained -> green chile
# green onions, chopped -> green onion
# jalapeno pepper, chopped -> jalapeno pepper
# egg, beaten -> egg
# cornstarch -> cornstarch
# garlic salt -> salt
# chicken tenders -> chicken tender
# vegetable oil -> vegetable oil
# cider vinegar -> cider vinegar
# white sugar -> sugar
# chicken broth -> chicken broth
# ketchup -> ketchup
# soy sauce -> soy sauce
# salt -> salt
# sea salt -> sea salt
# lobster tails -> lobster tail
# butter, melted -> butter
# olive oil -> olive oil
# poultry seasoning -> poultry seasoning
# dried parsley flakes -> parsley flake
# salt -> salt
# paprika -> paprika
# freshly ground black pepper -> black pepper
# turkey legs -> turkey leg
# fresh blueberries -> blueberry
# all-purpose flour, more as needed -> all purpose flour
# baking soda -> soda
# ground cinnamon -> ground cinnamon
# salt -> salt
# sourdough starter, room temperature -> sourdough starter room temperature
# white sugar -> sugar
# egg -> egg
# unsalted butter, melted and cooled -> butter
# vanilla extract -> vanilla extract
# white sugar -> sugar
# all-purpose flour -> all purpose flour
# unsalted butter -> butter
# ground cinnamon -> ground cinnamon
# chunk chicken breast, drained and flaked -> chunk chicken breast
# green onions, chopped -> green onion
# shredded sharp Cheddar cheese -> Cheddar cheese
# shredded pepperjack cheese -> pepperjack cheese
# hot pepper sauce (such as Frank's RedHot®) -> hot sauce pepper sauce Frank RedHot ®
# ranch dressing mix -> ranch dressing mix
# oil for frying -> oil
# all-purpose flour -> all purpose flour
# eggs, beaten -> egg
# plain bread crumbs -> bread crumb
# potatoes, unpeeled -> potato
# eggs -> egg
# uncooked spiral pasta -> pasta
# ...
# sour cream -> cream
# milk -> milk
# frozen hash brown potatoes -> potato
# chopped onion -> onion
# shredded Cheddar cheese -> Cheddar cheese
# NO YOLKS® Extra Broad Noodles -> ® Extra Broad Noodles
# vegetable oil -> vegetable oil
# fresh sliced mushrooms -> mushroom
# onion, thinly sliced -> onion
# garlic, minced -> garlic
# flank steak or London broil, cut into thin strips -> flank steak London broil strip
# flour, divided -> flour
# salt -> salt
# pepper -> pepper
# butter -> butter
# beef broth -> beef broth
# low-fat sour cream -> cream
# tomato paste -> tomato paste
# paprika -> paprika
# chopped Italian parsley -> parsley
# boneless, skinless chicken thighs -> boneless skinless chicken thigh
# soy sauce -> soy sauce
# orange juice -> orange juice
# olive oil -> olive oil
# ketchup -> ketchup
# chopped fresh parsley -> parsley
# garlic, minced -> garlic
# lemon juice -> lemon juice
# dried oregano -> oregano
# ground black pepper -> ground black pepper
# Red Delicious apples, finely chopped -> Red Delicious apple
# hulled and halved strawberries -> strawberry
# finely chopped rhubarb -> rhubarb
# white sugar -> sugar
# water -> water
# vanilla extract, or to taste -> vanilla extract
# lobster tails -> lobster tail
# butter, divided -> butter
# minced shallots -> shallot
# Salt, to taste -> salt
# diced mushrooms (Optional) -> mushroom
# all-purpose flour -> all purpose flour
# cognac or brandy -> cognac
# whole milk -> whole milk
# creme fraiche or heavy cream -> creme fraiche cream
# chopped fresh tarragon -> tarragon
# Cayenne pepper, to taste -> Cayenne pepper
# fine dried bread crumbs -> bread crumb
# freshly grated Parmigiano-Reggiano cheese -> Parmigiano Reggiano cheese
# melted butter -> butter
# angel hair pasta -> angel hair pasta
# extra virgin olive oil -> extra oil virgin oil olive oil
# sliced fresh mushrooms -> mushroom
# medium shrimp, peeled and deveined -> shrimp
# champagne -> champagne
# salt -> salt
# minced shallots -> shallot
# plum tomatoes, diced -> plum tomato
# heavy cream, divided -> cream
# salt and pepper to taste -> salt pepper
# chopped fresh parsley -> parsley
# freshly grated Parmesan cheese -> Parmesan cheese
# chuck roast, or more to taste -> chuck roast
# olive oil, divided -> olive oil
# apple cider vinegar -> apple cider vinegar
# onion, diced -> onion
# green bell peppers, diced -> green bell pepper
# chicken stock -> chicken stock
# water -> water
# diced tomatoes -> tomato
# black beans -> black bean
# light red kidney beans -> red kidney bean
# dark red kidney beans -> red kidney bean
# brown sugar -> sugar
# tomato paste -> tomato paste
# chili powder -> chili powder
# barbecue sauce -> barbecue sauce
# ketchup -> ketchup
# minced garlic -> garlic
# ground cumin -> ground cumin
# hot sauce (such as Valentina®) -> hot sauce Valentina ®
# mustard -> mustard
# Worcestershire sauce -> worcestershire sauce
# salt to taste -> salt
# molasses -> molasse
# honey -> honey
# white sugar -> sugar
# butter, cut into pieces -> butter piece
# grated lemon zest -> lemon
# ground anise seed -> anise seed
# ground ginger -> ground ginger
# ground nutmeg -> ground nutmeg
# ground cloves -> ground
# ground cinnamon -> ground cinnamon
# ground cardamom -> ground cardamom
# baking soda -> soda
# water -> water
# all-purpose flour, divided -> all purpose flour
# cocoa powder  -> cocoa powder
# baking powder -> powder
# eggs -> egg
# cornstarch -> cornstarch
# beef flank steak -> beef flank steak
# water -> water
# soy sauce -> soy sauce
# brown sugar -> sugar
# shredded carrots -> carrot
# green onions, chopped -> green onion
# olive oil -> olive oil
# garlic, minced -> garlic
# minced fresh ginger root -> ginger root
# ground beef -> ground beef
# chili powder -> chili powder
# paprika -> paprika
# ground cumin -> ground cumin
# garlic powder -> garlic powder
# salt -> salt
# tomato sauce -> tomato sauce
# water -> water
# all-purpose flour, divided -> all purpose flour
# sugar -> sugar
# cooking oil -> cook oil
# corn tortillas -> corn tortilla
# shredded American cheese -> cheese
# water -> water
# white sugar -> sugar
# fresh lavender blossoms -> lavender blossom
# minced garlic -> garlic
# vodka -> vodka
# heavy whipping cream -> whipping cream
# tomato sauce -> tomato sauce
# crushed tomatoes -> tomato
# freshly grated Parmesan cheese -> Parmesan cheese
# chopped fresh basil -> basil
# chopped fresh parsley -> parsley
# Yukon Gold potatoes -> Yukon Gold potato
# kosher salt -> salt
# milk -> milk
# salted butter, divided -> butter
# shredded white Cheddar cheese -> Cheddar cheese
# sour cream -> cream
# egg yolk -> egg yolk
# kosher salt, divided -> salt
# ground black pepper, divided -> ground black pepper
# olive oil -> olive oil
# diced onion -> onion
# diced carrot -> carrot
# ground lamb -> ground lamb
# ground beef sirloin -> ground beef sirloin
# all-purpose flour -> all purpose flour
# finely chopped fresh rosemary -> rosemary
# finely chopped fresh thyme -> thyme
# beef stock -> beef stock
# tomato paste -> tomato paste
# Worcestershire sauce -> worcestershire sauce
# frozen green peas -> green pea
# chopped fresh parsley, or to taste -> parsley
# ground beef -> ground beef
# hot mashed potatoes -> hot potato
# Philadelphia Cream Cheese, cubed -> Philadelphia Cream Cheese
# Kraft Shredded Cheddar Cheese, divided -> Kraft Shredded Cheddar Cheese
# garlic, minced -> garlic
# frozen mixed vegetables, thawed -> vegetable
# beef gravy -> beef gravy
# russet potatoes, peeled and cut into 1-inch cubes -> russet potato cube
# vegan mayonnaise -> vegan mayonnaise
# soy milk -> soy milk
# olive oil -> olive oil
# vegan cream cheese substitute (such as Tofutti) -> vegan cream cheese substitute Tofutti
# salt -> salt
# vegetable oil -> vegetable oil
# yellow onion, chopped -> yellow onion
# carrots, chopped -> carrot
# celery, chopped -> celery
# frozen peas -> pea
# tomato, chopped -> tomato
# Italian seasoning -> seasoning
# garlic, minced, or more to taste -> garlic
# ground black pepper to taste -> ground black pepper
# vegetarian ground beef substitute -> vegetarian ground beef substitute
# shredded Cheddar-style soy cheese -> Cheddar style soy cheese
# confectioners' sugar -> confectioner sugar
# milk, or as needed -> milk
# vanilla extract -> vanilla extract
# dry roasted salted peanuts, finely chopped -> peanut
# pound cake, cut into bize-size cubes -> pound cake size cube
# cream cheese, softened -> cream cheese
# butter, softened -> butter
# confectioners' sugar -> confectioner sugar
# vanilla extract -> vanilla extract
# flaked coconut -> coconut
# ground cinnamon -> ground cinnamon
# white chocolate chips -> white chocolate chip
# heavy whipping cream, or more as needed -> whipping cream
# light corn syrup -> corn syrup
# butter -> butter
# salt -> salt
# vanilla extract -> vanilla extract
# potatoes, peeled and halved -> potato
# all-purpose flour, plus extra for dusting -> all purpose flour
# melted butter -> butter
# salt -> salt
# white sugar -> sugar
# butter, melted -> butter
# eggs -> egg
# vanilla extract -> vanilla extract
# all-purpose flour -> all purpose flour
# baking soda -> soda
# salt -> salt
# sour cream -> cream
# chopped walnuts -> walnut
# medium bananas, sliced -> medium banana
# Eagle Brand sweetened condensed milk (not evaporated milk) -> Eagle Brand condensed milk milk
# semisweet chocolate chips -> semisweet chocolate chip
# butter -> butter
# water -> water
# vanilla extract -> vanilla extract
# instant pistachio pudding mix -> pistachio pudding mix
# crushed pineapple, with juice -> pineapple juice
# miniature marshmallows -> marshmallow
# chopped walnuts -> walnut
# frozen whipped topping, thawed -> topping
# water -> water
# unfiltered apple cider vinegar -> apple cider vinegar
# fresh lemon juice -> lemon juice
# honey -> honey
# grated fresh ginger  -> ginger
# ground cayenne pepper -> ground cayenne pepper
# white sugar -> sugar
# butter, softened -> butter
# egg -> egg
# strawberry puree ->
# all-purpose flour -> all purpose flour
# vanilla extract -> vanilla extract
# baking powder -> powder
# salt -> salt
# white sugar -> sugar
# red colored sugar (Optional) -> red sugar
# butter -> butter
# white sugar -> sugar
# brown sugar -> sugar
# egg, beaten -> egg
# vanilla extract -> vanilla extract
# mashed bananas -> banana
# all-purpose flour -> all purpose flour
# baking powder -> powder
# salt -> salt
# semisweet chocolate chips -> semisweet chocolate chip
# regular rolled oats, plus additional -> oat
# whole wheat flour -> whole flour wheat flour
# brown sugar -> sugar
# baking soda -> soda
# baking powder -> powder
# salt -> salt
# melted butter -> butter
# vanilla extract -> vanilla extract
# buttermilk -> buttermilk
# Guinness -> Guinness
# water -> water
# neck, giblets, and liver from a turkey -> neck giblet liver turkey
# onion, quartered -> onion
# celery, sliced -> celery
# carrot, sliced -> carrot
# tangerines, zested -> tangerine
# whole black peppercorns -> black peppercorn
# bay leaf -> bay leaf
# cream cheese, softened -> cream cheese
# sour cream -> cream
# refried beans -> bean
# shredded Cheddar cheese -> Cheddar cheese
# shredded Monterey Jack cheese -> Monterey Jack cheese
# chopped green onions -> green onion
# dried parsley -> parsley
# taco seasoning mix -> taco seasoning mix
# hot pepper sauce -> hot sauce pepper sauce
# potatoes, peeled and quartered -> potato
# carrots, cut into large chunks -> carrot chunk
# onion, cut into wedges -> onion wedge
# water -> water
# sugar -> sugar
# cider vinegar -> cider vinegar
# garlic, minced -> garlic
# ground black pepper -> ground black pepper
# bay leaf -> bay leaf
# corned beef brisket with spice packet, cut in half -> beef brisket spice packet half
# cabbage, cut into wedges -> cabbage wedge
# vegetable oil, divided -> vegetable oil
# skinless, boneless chicken breast halves -> skinless boneless chicken breast half
# onion, chopped -> onion
# garlic, minced -> garlic
# chicken broth -> chicken broth
# water -> water
# chili powder, or to taste -> chili powder
# salt, or to taste -> salt
# crumbled dried oregano -> oregano
# white hominy, rinsed and drained -> white hominy
# tostada shells -> tostada shell
# soy sauce -> soy sauce
# brown sugar -> sugar
# water -> water
# onion, chopped -> onion
# garlic, minced -> garlic
# grated fresh ginger root -> ginger root
# ground black pepper -> ground black pepper
# dried oregano -> oregano
# crushed red pepper flakes (Optional) -> red pepper flake
# ground cayenne pepper (Optional) -> ground cayenne pepper
# ground paprika (Optional) -> ground paprika
# skinless chicken thighs -> skinless chicken thigh
# sauerkraut, drained and squeezed dry -> sauerkraut
# Thousand Island salad dressing -> Island
# refrigerated crescent rolls (such as Pillsbury) -> crescent roll Pillsbury
# thin-sliced cooked corned beef -> beef
# Swiss cheese -> cheese
# beaten egg white -> egg
# white sugar -> sugar
# cornstarch -> cornstarch
# ground cinnamon -> ground cinnamon
# salt -> salt
# fresh blueberries -> blueberry
# double-crust pie pastry, thawed -> crust pie pastry
# butter -> butter
# chicken, cut into 8 pieces -> chicken piece
# black pepper -> black pepper
# salt -> salt
# paprika -> paprika
# white pepper -> white pepper
# dried rosemary -> rosemary
# ground thyme -> ground thyme
# dried oregano -> oregano
# dried sage -> sage
# cayenne pepper -> cayenne pepper
# buttermilk -> buttermilk
# flour -> flour
# salt -> salt
# paprika -> paprika
# cayenne pepper -> cayenne pepper
# garlic powder -> garlic powder
# white pepper -> white pepper
# onion powder -> onion powder
# peanut oil for frying -> peanut oil
# salted butter -> butter
# carrots, or more to taste, peeled and sliced -> carrot
# celery, or more to taste, chopped -> celery
# onion, chopped -> onion
# ground thyme -> ground thyme
# dried oregano -> oregano
# salt, or to taste -> salt
# ground black pepper, or to taste -> ground black pepper
# chicken broth -> chicken broth
# water -> water
# chicken bouillon -> chicken bouillon
# bay leaves -> bay
# frozen skinless, boneless chicken breast halves -> skinless boneless chicken breast half
# thin egg noodles -> egg noodle
# dried parsley -> parsley
# zucchini -> zucchini
# pork sausage -> pork sausage
# dry bread crumbs -> bread crumb
# grated Parmesan cheese -> Parmesan cheese
# garlic, minced -> garlic
# spaghetti sauce -> spaghetti sauce
# shredded mozzarella cheese -> mozzarella cheese
# vegetable oil -> vegetable oil
# boneless lean beef, cubed -> beef
# garlic powder -> garlic powder
# salt -> salt
# ground black pepper -> ground black pepper
# water, divided -> water
# beef broth -> beef broth
# carrots, chopped -> carrot
# green onions, chopped -> green onion
# celery, chopped -> celery
# barley -> barley
# chopped fresh parsley -> parsley
# dried thyme -> thyme
# Basmati rice -> Basmati rice
# coconut milk -> coconut milk
# salt -> salt
# bacon (Optional) -> bacon
# fresh sweet corn, kernels cut from the cob -> corn kernel cob
# ground cumin -> ground cumin
# sea salt -> sea salt
# ground cayenne pepper -> ground cayenne pepper
# onion, chopped -> onion
# red bell pepper, chopped -> red bell pepper
# garlic, chopped -> garlic
# beer -> beer
# crumbled cotija cheese -> cotija cheese
# chopped fresh cilantro -> cilantro
# whole wheat flour -> whole flour wheat flour
# all-purpose flour -> all purpose flour
# wheat germ -> wheat germ
# ground flax seed -> seed
# poppy seeds -> seed
# dried onion flakes -> onion flake
# parsley flakes -> parsley flake
# dried basil -> basil
# dried oregano -> oregano
# garlic salt -> salt
# baking powder -> powder
# smoked paprika -> paprika
# cayenne pepper -> cayenne pepper
# water -> water
# extra-virgin olive oil -> extra oil virgin oil olive oil
# sesame oil -> sesame oil
# kosher salt to taste -> salt
# all-purpose flour -> all purpose flour
# eggs -> egg
# Italian-seasoned bread crumbs -> bread crumb
# skinless, boneless chicken breasts -> skinless boneless chicken breast
# unsalted butter, or more to taste, divided -> butter
# marinara sauce, or more to taste -> marinara sauce
# mozzarella cheese -> mozzarella cheese
# Parmesan cheese -> Parmesan cheese
# oregano -> oregano
# basil -> basil
# garlic powder -> garlic powder
# shortening -> shortening
# butter, softened -> butter
# white sugar, or to taste -> white sugar
# large eggs -> egg
# vanilla extract -> vanilla extract
# all-purpose flour -> all purpose flour
# salt -> salt
# chopped pecans (Optional) -> pecan
# confectioners' sugar, or as needed -> confectioner sugar
# bacon grease -> bacon grease
# unsalted butter -> butter
# onion, finely chopped -> onion
# celery, finely chopped -> celery
# chopped fresh parsley -> parsley
# chicken stock -> chicken stock
# heavy cream -> cream
# salt -> salt
# seasoned salt -> salt
# ground black pepper -> ground black pepper
# chili powder -> chili powder
# dried dill weed -> dill weed
# white sugar -> sugar
# cayenne pepper -> cayenne pepper
# fresh crabmeat -> crabmeat
# all-purpose flour -> all purpose flour
# water, or as needed -> water
# dry sherry (Optional) -> sherry
# garlic powder -> garlic powder
# onion powder -> onion powder
# crushed red pepper flakes -> red pepper flake
# freshly cracked black pepper -> black pepper
# pork shoulder roast  -> pork shoulder roast
# Creole-style butter injectable marinade (such as Tony Chachere's Roasted Garlic & Herb Marinade) -> style butter marinade Tony Chachere Roasted Garlic Herb Marinade
# butter -> butter
# shallots, chopped -> shallot
# elephant garlic, chopped -> elephant garlic
# water -> water
# sweet onions (such as Vidalia), peeled and quartered -> onion Vidalia
# red potatoes -> red potato
# baby carrots -> baby carrot
# celery, cut into 4 pieces -> celery piece
# water, divided -> water
# dry brown gravy mix -> gravy mix
# garlic powder -> garlic powder
# freshly cracked black pepper -> black pepper
# onion powder -> onion powder
# lean ground sirloin -> ground sirloin
# Mission® Fajita Flour Tortillas -> mission ® Fajita Flour Tortillas
# salt and ground black pepper to taste -> salt ground black pepper
# shredded sharp Cheddar cheese -> Cheddar cheese
# red tomato, cut into 1/4-inch slices -> red tomato slice
# green leaf lettuce -> green leaf lettuce
# red onion, sliced and separated into rings  -> red onion ring
# dill pickle slices -> pickle slice
# rolled oats -> oat
# unsweetened flaked coconut -> coconut
# light brown sugar -> sugar
# baking powder -> powder
# ground cinnamon -> ground cinnamon
# salt -> salt
# skim milk -> skim milk
# coconut oil, softened -> coconut oil
# egg, beaten -> egg
# vanilla extract -> vanilla extract
# blueberries -> blueberry
# refrigerated crescent rolls -> crescent roll
# cream cheese, softened -> cream cheese
# egg, separated -> egg
# white sugar -> sugar
#  fresh lemon juice -> lemon juice
# vanilla extract -> vanilla extract

# %%
len(clean_ing_list)
# Out:
# 6562

# %%
pd.DataFrame(clean_ing_list).value_counts().tail(60)
# Out:
# 0
# vegetable bouillon base Better Bouillon                   1
# vegetable corn pea carrot green bean lima bean            1
# vegetarian bean                                           1
# tuna                                                      1
# turkey broth                                              1
# turkey ham ham                                            1
# turkey liver                                              1
# turkey wing                                               1
# turnip                                                    1
# unbleached flour                                          1
# unbleached flour bread flour                              1
# vanilla bean                                              1
# warm milk                                                 1
# wasabi paste                                              1
# water amount                                              1
# water bean                                                1
# water cup filling                                         1
# vanilla wafer                                             1
# cabbage eighth                                            1
# cabbage leave                                             1
# cabbage ¼ slice                                           1
# can sauce jellied sauce cranberry sauce                   1
# candy                                                     1
# candy dragee                                              1
# cane sugar                                                1
# capicola coppa                                            1
# caramel macchiato coffee creamer International Delight    1
# carrot bite chunk                                         1
# Bruce ® Yams Cut Sweet Potatoes Syrup                     1
# Cajun seasoning                                           1
# California                                                1
# Campbell cream chicken soup                               1
# Cayenne pepper                                            1
# Cheddar Monterey Jack cheese blend                        1
# ® Extra Broad Noodles                                     1
# wheat pita bread                                          1
# wheat semolina flour Bob Red Mill ®                       1
# Medjool date                                              1
# Mexican oregano                                           1
# white flour whole flour wheat flour                       1
# white kidney bean                                         1
# white kidney bean cannellini                              1
# white potato                                              1
# white rice                                                1
# Colby cheese                                              1
# Cox apple ring                                            1
# yellow squash                                             1
# zucchini slice                                            1
# Brussels sprout                                           1
# water room temperature                                    1
# water steaming                                            1
# water texture                                             1
# wheat                                                     1
# wheat bread                                               1
# wheat cereal                                              1
# wheat germ                                                1
# yellow rice Vigo                                          1
# yellow sauce sport sauce pepper sauce Texas Petes ®       1
# wrapper                                                   1
# yam fry                                                   1
# Name: count, dtype: int64

# %%
clean_ing_list = list(set(clean_ing_list))

# %%
len(clean_ing_list)
# Out:
# 1182

# %%
import spacy
import re

# Carga del modelo de spaCy para español
nlp_es = spacy.load("es_core_news_sm")

# Palabras “esenciales” (en lemma) que siempre queremos mantener
ESSENTIAL_WORDS = {"aguacate", "canela", "albahaca", "sódico", "sodio"}  # ajusta según tu dominio

# Adjetivos esenciales que queremos preservar (en lemma).
# Ej.: “integral”, “fresco”, “verde”, etc.
ESSENTIAL_ADJECTIVES = {
    "integral", "fresco", "verde", "rojo", "amarillo", "negro",
    "picante", "canola", "coco", "almendra", "rallado"
}

# Adverbios que, si aparecen, deseamos conservar (casos muy concretos).
ESSENTIAL_ADV = {"todo", "rising"}  # Ajusta según tu dominio

# Palabras que queremos excluir siempre (por ejemplo, “opcional”, “necesario”, etc.)
EXCLUDED_WORDS = {
    "opcional", "necesario", "grados", "f", "c", "gusto","pellizco", "pizca","cucharada","cucharadita",
    "taza","vaso","litro","mililitro","gramo","kilogramo","onza","gota","chorrito","puñado","unidad","lata",
    "tableta","trozo","diente","ramita","manojo","pieza","bolsa","copa", "m", "l", "xl","s", "temperatura", "ambiente",
    "caliente", "fría", "frío"}

# SUSTANTIVOS en español que queremos tratar como un “compuesto”
# cuando vayan precedidos por un adjetivo o compound (borrowed) 
# Ej.: “polvo” (powder), “aceite” (oil), “salsa” (sauce), “harina” (flour), etc.
TARGET_NOUNS = {
    "polvo",   # powder
    "aceite",  # oil
    "salsa",   # sauce
    "leche",   # milk
    "pasta",   # paste
    "harina"   # flour
}

def clean_ingredient_with_pos_es(text: str) -> str:
    """
    1) Reemplaza guiones "freeze-dried" -> "freeze dried"
    2) Analiza con POS tagging + dependencias usando spaCy (es_core_news_sm)
    3) Combina ADJ/compound + NOUN si el NOUN está en TARGET_NOUNS
    4) Elimina palabras en EXCLUDED_WORDS
    5) Lematiza sustantivos para unificar sing/plural
    6) Retorna un string limpio
    """
    # Quitar guiones
    text = text.replace("-", " ")
    
    text = re.sub(r"\(.*?\)", "", text)  # Eliminar paréntesis y su contenido

    doc = nlp_es(text)
    
    processed = set()  # Para no procesar 2 veces el mismo token
    keep_tokens = []

    for token in doc:
        # Si ya está procesado en un paso anterior, lo ignoramos
        if token.i in processed:
            continue
        
        lemma = token.lemma_.lower()  # lemma en minúsculas
        lower = token.text.lower()  # texto en minúsculas

        # 1) Ignorar palabras excluidas (p. ej. "opcional", "gusto", etc.)
        if lemma in EXCLUDED_WORDS:
            continue

        if lower in ESSENTIAL_WORDS:
            keep_tokens.append(lower)

        # 2) Revisar si es un adjetivo (ADJ) o compound (dep_) que modifica un NOUN
        #    En español, 'compound' es menos frecuente, pero a veces aparece
        #    en términos importados o expresiones compuestas.
        if token.dep_ in ("amod", "compound") and token.head.pos_ == "NOUN":
            head_lemma = token.head.lemma_.lower()
            # Si el sustantivo principal está en TARGET_NOUNS (p. ej. 'polvo')
            if head_lemma in TARGET_NOUNS:
                # Combinamos: "chili" + "powder" => "chili powder"
                # En español podría ser "ajo" + "polvo" => "ajo polvo"
                combined = f"{lemma} {head_lemma}"
                keep_tokens.append(combined)
                
                # Marcamos como procesados (para no añadirlos de nuevo)
                processed.add(token.i)
                processed.add(token.head.i)
                continue

        # 3) Si es un sustantivo (NOUN) o nombre propio (PROPN) (no procesado antes):
        if token.pos_ in ["NOUN", "PROPN"] and token.i not in processed:
            keep_tokens.append(lemma)  # lematizado

        # 4) Si es un adjetivo (ADJ) y está en la lista de esenciales, lo conservamos
        elif token.pos_ == "ADJ":
            if lemma in ESSENTIAL_ADJECTIVES:
                keep_tokens.append(lemma)

        # 5) Si es un adverbio (ADV) y está en ESSENTIAL_ADV, lo conservamos
        elif token.pos_ == "ADV":
            if lemma in ESSENTIAL_ADV:
                keep_tokens.append(lemma)        

    # Reconstruimos en un solo string
    cleaned = " ".join(keep_tokens)
    # Limpiamos espacios, comas, puntos sobrantes
    cleaned = re.sub(r"\s+", " ", cleaned).strip(",. ")

    return cleaned

# %%
clean_ingredient_with_pos_es("Canela molida")
# Out:
# 'canela'

# %%
recetas = pd.read_json(r"recetas_scrapper\recetas_dap_no_delay.jsonl", lines = True)
ing_lista = [r["nombre"] for r in recetas.loc[74:, "ingredientes"]]
all_ing_lista = [item for sublist in ing_lista for item in sublist]
# Out:
# C:\Users\yanru\AppData\Local\Temp\ipykernel_2616\681471977.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   recetas = pd.read_json(r"recetas_scrapper\recetas_dap_no_delay.jsonl", lines = True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 recetas = pd.read_json(r"recetas_scrapper\recetas_dap_no_delay.jsonl", lines = True)
#       2 ing_lista = [r["nombre"] for r in recetas.loc[74:, "ingredientes"]]
#       3 all_ing_lista = [item for sublist in ing_lista for item in sublist]
#
# File c:\Users\yanru\anaconda3\envs\hotdog\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File c:\Users\yanru\anaconda3\envs\hotdog\Lib\site-packages\pandas\io\json\_json.py:1023, in JsonReader.read(self)
#    1021         data = ensure_str(self.data)
#    1022         data_lines = data.split("\n")
# -> 1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
#    1025     obj = self._get_object_parser(self.data)
#
# File c:\Users\yanru\anaconda3\envs\hotdog\Lib\site-packages\pandas\io\json\_json.py:1051, in JsonReader._get_object_parser(self, json)
#    1049 obj = None
#    1050 if typ == "frame":
# -> 1051     obj = FrameParser(json, **kwargs).parse()
#    1053 if typ == "series" or obj is None:
#    1054     if not isinstance(dtype, bool):
#
# File c:\Users\yanru\anaconda3\envs\hotdog\Lib\site-packages\pandas\io\json\_json.py:1187, in Parser.parse(self)
#    1185 @final
#    1186 def parse(self):
# -> 1187     self._parse()
#    1189     if self.obj is None:
#    1190         return None
#
# File c:\Users\yanru\anaconda3\envs\hotdog\Lib\site-packages\pandas\io\json\_json.py:1403, in FrameParser._parse(self)
#    1399 orient = self.orient
#    1401 if orient == "columns":
#    1402     self.obj = DataFrame(
# -> 1403         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404     )
#    1405 elif orient == "split":
#    1406     decoded = {
#    1407         str(k): v
#    1408         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1409     }
#
# ValueError: Expected object or value

# %%
clean_ing_lista = []
for item in all_ing_lista:
    clean_ing = clean_ingredient_with_pos_es(item)
    clean_ing_lista.append(clean_ing)

    print(f"{item} -> {clean_ing}")
# Out:
# Cebolla -> cebolla
# Berenjena -> berenjena
# Pimiento rojo morrón -> pimiento rojo morrón
# Pimiento verde grande -> pimiento verde
# Tomates en conserva natural -> tomates conserva
# Aceite de oliva virgen extra -> aceite virgen
# Bicarbonato sódico o azúcar -> bicarbonato sódico azúcar
# Sal necesaria -> sal
# Leche -> leche
# Clara de huevo Lonchas -> clara huevo lonchas
# Harina de repostería -> harina repostería
# Azúcar -> azúcar
# Mantequilla -> mantequilla
# Levadura química , 4 cucharaditas -> levadura
# Sal , un pellizco -> sal
# Extracto de vainilla -> extracto vainilla
# Harina de maíz amarilla (no maizena ni precocida ni polenta) -> harina maíz amarillo
# Nueces (peso ya peladas y molidas) -> nueces
# Manteca de cerdo a temperatura ambiente -> manteca cerdo
# Azúcar glasé y más para espolvorear -> azúcar glasé
# Canela molida -> canela
# Rape fresco 2 colas medianas aproximadamente 500 g -> rape fresco cola
# Langostinos crudos -> langostino
# Huevo -> huevo
# Pan rallado una cucharada sopera -> pan rallado
# Cebolla -> cebolla
# Diente de ajo -> ajo
# Perejil fresco al gusto -> perejil fresco
# Sal y pimienta al gusto -> sal
# Vino blanco -> vino
# Levadura fresca de panadería -> levadura fresca panadería
# Leche -> leche
# Harina de fuerza -> harina fuerza
# Mantequilla -> mantequilla
# Azúcar -> azúcar
# Ralladura de naranja -> ralladura naranja
# Huevo M -> huevo
# Cardamomo molido -> cardamomo
# Tortas cenceñas -> tortas
# Caldo de pescado o fumet -> caldo pescado
# Mero ->
# Calamar -> calamar
# Cebolla -> cebolla
# Diente de ajo -> ajo
# Tomate maduro -> tomate
# Pimiento rojo -> pimiento rojo
# Azafrán unas hebras -> hebra
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Tomillo seco 2 cucharaditas -> tomillo
# Orégano seco 2 cucharaditas -> orégano
# Pimienta negra molida -> pimienta negro
# Pimiento verde -> pimiento verde
# Coliflor -> coliflor
# Aceite de oliva virgen extra -> aceite virgen
# Vinagre de arroz -> vinagre arroz
# Salsa de soja baja en sal -> salsa soja sal
# Azúcar moreno -> azúcar
# Diente de ajo -> ajo
# Laurel -> laurel
# Guindilla o chile rojo -> guindilla chile rojo
# Cebollino o tallos verdes de cebolleta -> cebollino tallo verde cebolleta
# Pollo de corral (de unos dos kilos) -> pollo
# Diente de ajo -> ajo
# Mantequilla derretida (o manteca, o aceite de oliva) -> mantequilla
# Agua -> agua
# Sal 2 cucharaditas -> sal
# Pimienta negra molida 1 cucharadita -> pimienta negro
# Judías pintas en conserva -> judía pinta conserva
# Pimiento rojo -> pimiento rojo
# Pepinillo (pequeño) -> pepinillo
# Cebolleta -> cebolleta
# Aceite de oliva virgen extra -> aceite virgen
# Melaza o miel de caña -> melaza miel caña
# Zumo de limón -> zumo limón
# Eneldo fresco 4-5 ramas -> eneldo fresco rama
# Perejil fresco 4-5 ramas -> perejil fresco rama
# Menta fresca 4-5 ramas -> menta fresca rama
# Comino molido 1/2 cucharadita -> comino
# Brócoli -> brócoli
# Mayonesa -> mayonesa
# Huevo cocido -> huevo
# Alcaparras -> alcaparras
# Pepinillo -> pepinillo
# Cebolla -> cebolla
# Mostaza de Dijon -> mostaza dijon
# Cebollino -> cebollino
# Diente de ajo (para la salsa) -> ajo
# Cilantro fresco o perejil (para la salsa) -> cilantro fresco perejil
# Chile molido (para la salsa) -> chile
# Comino molido o en grano (para la salsa) -> comino grano
# Pimentón dulce (para la salsa) -> pimentón
# Pimienta negra molida (para la salsa) -> pimienta negro
# Sal (para la salsa y la tarta) -> sal
# Aceite de oliva virgen extra (para la salsa y la tarta) -> aceite virgen
# Cebolla -> cebolla
# Espinaca congelada (peso escurrido) -> espinaca
# Ralladura de limón 1 1/2 cucharadita -> ralladura limón
# Zumo de limón 1 1/2 cucharadita -> zumo limón
# Hojaldre lámina redonda -> hojaldre lámina
# Queso feta -> queso
# Patata -> patata
# Aceite de oliva suave -> aceite oliva
# Azúcar -> azúcar
# Huevos talla M -> huevos
# Cacao en polvo cucharadas rasas -> cacao polvo rasa
# Colorante alimentario en gel rojo -> gel rojo
# Extracto de vainilla cucharaditas -> extracto vainilla
# Leche -> leche
# Zumo de limón cucharadita -> zumo limón
# Harina de repostería -> harina repostería
# Bicarbonato sódico cucharadita -> bicarbonato sódico
# Vinagre cucharadita -> vinagre
# Queso crema -> queso
# Mantequilla -> mantequilla
# Azúcar glas -> azúcar gla
# Esencia de vainilla cucharadita -> esencia vainilla
# Chocolate blanco o Candy Mealts rojos -> chocolate candy mealts rojo
# Harina de trigo -> harina trigo
# Aceite de oliva virgen extra -> aceite virgen
# Azúcar moreno -> azúcar
# Cacao en polvo azucarado (Caoflor o similar) -> cacao polvo
# Levadura química -> levadura
# Leche o bebida de avena (u otra bebida vegetal) -> leche bebida avena
# Sal una pizca -> sal
# Margarina -> margarina
# Chocolate de cobertura -> chocolate cobertura
# Chocolate negro de cobertura -> chocolate negro cobertura
# Leche entera -> leche
# Zumo de limón -> zumo limón
# Harina de trigo -> harina trigo
# Cacao en polvo -> cacao polvo
# Levadura química -> levadura
# Sal pellizco -> sal
# Mantequilla (a temperatura ambiente) -> mantequilla
# Azúcar moreno -> azúcar
# Azúcar blanquilla -> azúcar blanquilla
# Huevos tamaño "M" (a temperatura ambiente) -> huevos tamaño
# Esencia de vainilla -> esencia vainilla
# Agua hirviendo -> agua
# Nata líquida -> nata
# Boniato -> boniato
# Naranjas -> naranjas
# Miso blanco -> miso
# Canela molida una pizca -> canela canela
# Miel -> miel
# Salsa de soja -> salsa soja
# Aceite de oliva virgen extra -> aceite virgen
# Salsa Worcestershire -> salsa worcestershire
# Vinagre de Jerez -> vinagre jerez
# Cebollino -> cebollino
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Arroz de grano largo tipo basmati, jazmín, thai -> arroz grano tipo basmati jazmín
# Zanahoria -> zanahoria
# Gamba -> gamba
# Guisantes -> guisantes
# Jamón de York en taquitos -> jamón york taquito
# Huevos -> huevos
# Salsa de soja -> salsa soja
# Azúcar -> azúcar
# Aceite de oliva virgen extra -> aceite virgen
# Pepino pequeño -> pepino
# Yogur griego natural -> yogur griego
# Cebolleta -> cebolleta
# Diente de ajo -> ajo
# Vinagre de manzana -> vinagre manzana
# Aceite de oliva virgen extra -> aceite virgen
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Menta fresca -> menta fresco
# Harina de fuerza -> harina fuerza
# Levadura fresca de panadería -> levadura fresca panadería
# Azúcar (1 buena pizca) -> azúcar
# Sal (1/2 cucharadita) -> sal
# Agua templada -> agua
# Buttermilk o leche (ver introducción) -> buttermilk leche
# Miel -> miel
# Huevo batido para pintar -> huevo
# Hojaldre lámina rectangular -> hojaldre
# Salsa de tomate -> salsa tomate
# Albahaca fresca, unas hojas -> albahaca albahaca fresca hoja
# Jamón de York en lonchas -> jamón york loncha
# Queso Mozzarella rallado -> queso mozzarella rallado
# Frambuesas congeladas -> frambuesa
# Azúcar de caña líquido -> azúcar caña
# Cava (bebida) o champagne -> cava champagne
# Mantequilla sin sal atemperada -> mantequilla sal
# Azúcar moreno -> azúcar
# Yema de huevo -> yema huevo
# Harina de repostería -> harina repostería
# Cardamomo (cucharadita) -> cardamomo
# Canela molida (cucharadita) -> canela canela
# Sal 1 buena pizca -> sal
# Azúcar glasé -> azúcar glasé
# Zumo de limón necesario -> zumo limón
# Aceitunas verdes sin hueso - puñado generoso -> aceitunas verde hueso generoso
# Queso crema 3 a 4 cucharadas -> queso crema
# Yogur griego 1 a 2 cucharadas -> yogur
# Vinagre de manzana cucharadas -> vinagre manzana
# Sal y pimienta al gusto -> sal
# Aceite de oliva virgen extra cucharada -> aceite virgen
# Orégano seco cucharadita -> orégano
# Diente de ajo (opcional) -> ajo
# Bacon en lonchas -> bacon loncha
# Cebolla grande -> cebolla
# Diente de ajo -> ajo
# Azúcar moreno 4 cucharadas -> azúcar moreno
# Vinagre de manzana u otro tipo -> vinagre manzana tipo
# Sirope de arce o miel -> sirope arce miel
# Café (1 taza) -> café
# Comino molido -> comino
# Pimienta negra molida -> pimienta negro
# Bourbon o brandy -> bourbon
# Pechuga de pollo -> pechuga pollo
# Ricotta -> ricotta
# Jamón serrano en lonchas grandes y finas -> jamón loncha fina
# Queso parmesano rallado -> queso rallado
# Yema de huevo -> yema huevo
# Aceite de oliva virgen extra -> aceite virgen
# Ralladura de limón -> ralladura limón
# Salvia fresca -> salvia fresco
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Berenjena -> berenjena
# Diente de ajo -> ajo
# Comino molido (1/2 cucharadita) -> comino
# Pimentón dulce (1/2 cucharadita) -> pimentón
# Sal (1/4 cucharadita) -> sal
# Pimienta negra molida al gusto -> pimienta negro
# Tahini (1 cucharada rasa) -> tahini
# Aceite de oliva virgen extra (4 cucharadas) -> aceite virgen
# Zumo de limón -> zumo limón
# Sal gruesa -> sal gruesa
# Harina de trigo (para la masa) -> harina trigo
# Manteca de cerdo (para la masa) -> manteca cerdo
# Agua (para la masa) -> agua
# Queso ricotta -> queso
# Azúcar -> azúcar
# Harina de repostería -> harina repostería
# Levadura química -> levadura
# Azafrán unas hebras -> hebra
# Ralladura de limón -> ralladura limón
# Ralladura de naranja -> ralladura naranja
# Yema de huevo L -> yema huevo
# Azúcar glas para decorar -> gla
# Calamares frescos -> calamar fresco
# Harina de trigo -> harina trigo
# Agua -> agua
# Sifón un chorrito ->
# Sal -> sal
# Huevo -> huevo
# Bicarbonato sódico 1/2 cucharada -> bicarbonato sódico
# Coñac un chorrito -> coñac
# Aceite de oliva virgen extra para freír -> aceite virgen
# Limón (opcional) -> limón
# Sobras de un plato de pasta -> sobras plato pasta
# Harina de trigo vasos -> harina trigo vasos
# Yema de huevo -> yema huevo
# Clara de huevo -> clara huevo
# Leche vaso -> leche
# Aceite de girasol -> aceite girasol
# Coca-Cola (refresco de cola) -> coca cola
# Vino tinto vaso -> vino tinto
# Hojaldre redondo o rectangular -> hojaldre redondo
# Huevo batido -> huevo
# Semillas de sésamo tostado -> semillas sésamo
# Queso crema -> queso
# Sardinas en conserva (lata en aceite) -> sardinas conserva
# Azúcar -> azúcar
# Ralladura de limón -> ralladura limón
# Azúcar vainillado 1 cucharadita -> azúcar
# Almendra molida -> almendra
# Clara de huevo -> clara huevo
# Yema de huevo -> yema huevo
# Sal una pizca -> sal
# Harina de trigo -> harina trigo
# Agua -> agua
# Aceite de oliva virgen extra -> aceite virgen
# Levadura seca de panadería cucharadas rasas -> levadura panadería rasa
# Azúcar cucharadita -> azúcar
# Sal -> sal
# Queso Mozzarella -> queso mozzarella
# Queso ricotta -> queso
# Queso de cabra -> queso cabra
# Diente de ajo -> ajo
# Albahaca fresca, al gusto -> albahaca albahaca fresca
# Aceite de oliva virgen extra al gusto -> aceite virgen
# Sal y pimienta al gusto -> sal
# Farfalle o la pasta que gusten -> farfalle pasta
# Calabacín mediano -> calabacín
# Philadelphia Vegetal (2 cucharadas generosas) -> philadelphia vegetal
# Levadura nutricional -> levadura
# Pimienta negra molida a gusto -> pimienta negro
# Cebolla en polvo (opcional) -> cebolla polvo
# Tallarines -> tallarines
# Yema de huevo -> yema huevo
# Queso parmesano ->
# Guanciale (papada de cerdo curada) -> guanciale
# Agua de agua de cocción de la pasta -> agua agua cocción pasta
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Anchoas (boquerones o bocartes) limpias y abiertas en libro -> libro
# Cebolleta -> cebolleta
# Pimiento verde picante -> pimiento verde
# Vinagre de sidra -> vinagre sidra
# Diente de ajo -> ajo
# Perejil fresco -> perejil fresco
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Tomate -> tomate
# Zanahoria -> zanahoria
# Cebolla -> cebolla
# Caldo de verduras -> caldo verdura
# Aceite de oliva virgen extra tres cucharadas -> aceite virgen
# Harina de trigo una cucharada -> harina trigo
# Laurel una hoja -> laurel hoja
# Diente de ajo -> ajo
# Frambuesas (pueden ser congeladas) -> frambuesas
# Agua -> agua
# Azúcar cucharadas -> azúcar
# Limón -> limón
# Melón -> melón
# Pepitas de chocolate -> pepitas chocolate
# Huevo -> huevo
# Azúcar -> azúcar
# Café (bebida) -> café
# Leche -> leche
# Caramelo líquido -> caramelo
# Canónigos -> canónigos
# Uvas -> uvas
# Queso curado -> queso
# Nueces peladas -> nuez
# Cebolleta -> cebolleta
# Rabanitos -> rabanitos
# Aceite de oliva virgen extra -> aceite virgen
# Vinagre de manzana -> vinagre manzana
# Sal -> sal
# Queso Roquefort troceado -> queso roquefort
# Vino blanco -> vino
# Nata líquida -> nata
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Endibias -> endibias
# Surimi paquete -> surimi
# Almendras laminadas cucharadas -> almendra
# Patatas -> patatas
# Dientes de ajo -> dientes ajo
# Huevos -> huevos
# Aceite de oliva virgen extra -> aceite virgen
# Queso feta -> queso
# Pesto de albahaca -> pesto albahaca albahaca
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Mejillones en escabeche -> mejillón escabeche
# Boquerones en vinagre -> boquerones vinagre
# Anchoas -> anchoas
# Pan de barra -> pan barra
# Gulas (sucedáneo de angulas) -> gulas
# Diente de ajo -> ajo
# Guindilla -> guindilla
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Leche entera -> leche
# Azúcar -> azúcar
# Yemas de huevo -> yemas huevo
# Huevo -> huevo
# Almidón de maíz (Maizena) -> almidón maíz
# Galletas tipo María hojaldradas -> galletas tipo maría
# Leche ligeramente tibia -> leche
# Ron añejo un chorrito ->
# Canela molida -> canela
# Aceite de girasol para freír -> aceite girasol
# Kale en hojas -> kale hoja
# Queso feta -> queso
# Arándanos ->
# Almendras laminadas o en bastones -> almendra bastones
# Zumo de limón -> zumo limón
# Mermelada de albaricoque o compota, mejor casera -> mermelada compota
# Aceite de oliva virgen extra -> aceite virgen
# Vinagre de manzana -> vinagre manzana
# Diente de ajo pequeño sin germen o medio -> ajo germen
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Patata -> patata
# Berenjena -> berenjena
# Sal y pimienta al gusto -> sal
# Aceite de oliva virgen extra para freír los ingredientes -> aceite virgen ingrediente
# Cebolla -> cebolla
# Chorizo fresco -> chorizo fresco
# Pimiento rojo -> pimiento rojo
# Pimiento verde italiano -> pimiento verde
# Huevo -> huevo
# Diente de ajo (2 pequeños o uno hermoso) -> ajo
# Mantequilla en punto pomada -> mantequilla punto
# Sal una pizca -> sal
# Azúcar glasé -> azúcar glasé
# Clara de huevo -> clara huevo
# Harina de trigo -> harina trigo
# Vainilla -> vainilla
# Chocolate fondant -> chocolate fondant
# Almendra granillo o picada -> almendra granillo
# Calabacín -> calabacín
# Cebolla -> cebolla
# Queso feta -> queso
# Queso de rulo de cabra -> queso rulo cabra
# Huevo -> huevo
# Eneldo fresco -> eneldo fresco
# Perejil fresco -> perejil fresco
# Hierbabuena fresca -> hierbabuena fresco
# Pan rallado -> pan rallado
# Harina de trigo -> harina trigo
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Aceite de oliva virgen extra -> aceite virgen
# Clara de huevo -> clara huevo
# Sal pellizco -> sal
# Azúcar -> azúcar
# Harina de maíz refinada -> harina maíz
# Nata líquida para montar (bien fría) ->
# Azúcar glasé -> azúcar glasé
# Fresa -> fresa
# Arándanos ->
# Arroz para Sushi para el arroz de sushi -> arroz sushi arroz sushi
# Agua para el arroz de sushi -> agua arroz sushi
# Vinagre de arroz para el aderezo del arroz -> vinagre arroz aderezo arroz
# Azúcar para el aderezo del arroz -> azúcar aderezo arroz
# Sal para el aderezo del arroz -> sal aderezo arroz
# Alga nori hojas -> alga hoja
# Salmón crudo en tiras finas y cortas -> salmón crudo tira corta
# Atún fresco crudo en tiras finas y cortas -> atún fresco tira corta
# Pepino cortado en tiras finas -> tira
# Queso crema tarrina -> queso crema
# Aguacate cortado en tiras finas -> aguacate aguacate tira
# Cebolla frita crujiente al gusto -> cebolla
# Coles de Bruselas -> coles bruselas
# Aceite de oliva virgen extra -> aceite virgen
# Pimienta negra molida al gusto -> pimienta negro
# Sal al gusto -> sal
# Limón (opcional) -> limón
# Diente de ajo bien frescos -> ajo fresco
# Guindilla roja seca (o fresca) -> guindilla rojo
# Aceite de oliva virgen extra -> aceite virgen
# Perejil fresco (un manojo) -> perejil fresco
# Vinagre de vino blanco o sidra -> vinagre vino sidra
# Pimentón dulce o picante al gusto (opcional) -> pimentón
# Manzana pelada y cortada -> manzana
# Panela o azúcar moreno (o incluso menos cantidad) -> panela azúcar
# Canela molida y/o vainilla (1/2 cucharadita de cada, aprox.) -> canela canela vainilla
# Nuez moscada molida -> nuez
# Zumo de limón -> zumo limón
# Huevo L -> huevo
# Aceite de oliva virgen extra -> aceite virgen
# Leche -> leche
# Harina de avena -> harina avena
# Harina de espelta integral o trigo -> harina espelta integral trigo
# Levadura química -> levadura
# Sal 1 pizca -> sal
# Coco rallado para decorar (opcional) -> coco rallado
# Solomillo (ternera o buey) cortado a cuchillo, para el tartar -> solomillo cuchillo
# Brioche cuatro rebanadas -> brioche rebanada
# Chile chipotle una cucharadita de pasta, para aliñar el tartar -> chile pasta tartar
# Yema de huevo para aliñar el tartar -> yema huevo tartar
# Tomate seco para el tartar -> tomate
# Salsa Perrins una cucharada, para aliñar el tartar -> salsa perrins tartar
# Ralladura de limón una cucharada de postre, para aliñar el tartar -> ralladura postre tartar
# Sal en escamas una pizca, para aliñar el tartar -> sal escama tartar
# Pimienta negra molida una pizca, para aliñar el tartar -> pimienta negro tartar
# Aceite de oliva virgen extra una cucharada sopera, para aliñar el tartar -> aceite virgen sopera tartar
# Nata líquida para cocinar para la salsa blanca ->
# Yogur griego para la salsa blanca -> yogur
# Mayonesa para la salsa blanca -> mayonesa
# Sal y pimienta al gusto para la salsa blanca -> sal
# Mostaza de Dijon cuatro cucharadas para la salsa de mostaza -> mostaza dijon salsa mostaza
# Mostaza a la antigua dos o tres cucharadas para la salsa de mostaza -> salsa mostaza
# Agua ocho cucharadas para la salsa de mostaza -> agua salsa mostaza
# Jarabe de glucosa o de azúcar (almíbar) para la salsa de mostaza -> jarabe azúcar salsa mostaza
# Pepinillo para decorar -> pepinillo
# Flores comestibles para decorar -> flores comestibl
# Brotes para decorar -> brotes
# Guindilla verde fresca o roja, para decorar -> guindilla verde fresca rojo
# Mantequilla para untar en el pan brioche -> mantequilla pan brioche
# Alcaparras para decorar -> alcaparras
# Pechuga de pollo no muy grandes -> pechuga pollo
# Sidra de manzana -> sidra manzana
# Pimienta negra en grano -> pimienta negro grano
# Cardamomo -> cardamomo
# Laurel -> laurel
# Clavo de olor -> clavo olor
# Zanahoria -> zanahoria
# Miel -> miel
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Aceite de oliva virgen extra -> aceite virgen
# Avellanas tostada molida -> avellana
# Harina de repostería -> harina repostería
# Azúcar moreno -> azúcar
# Huevo M -> huevo
# Limón -> limón
# Mantequilla -> mantequilla
# Leche -> leche
# Miel , 1 cucharada -> miel
# Levadura química -> levadura
# Esencia de vainilla al gusto -> esencia vainilla
# Mantequilla para engrasar el molde -> mantequilla molde
# Cerveza Guinness -> cerveza guinness
# Mantequilla -> mantequilla
# Cacao en polvo -> cacao polvo
# Azúcar -> azúcar
# Nata líquida con 35% de materia grasa -> nata materia
# Huevo -> huevo
# Extracto de vainilla una cucharadita -> extracto vainilla
# Harina de repostería -> harina repostería
# Bicarbonato sódico dos cucharaditas y media -> bicarbonato sódico
# Queso crema -> queso
# Azúcar glas -> azúcar gla
# Zanahoria -> zanahoria
# Manzana -> manzana
# Nata líquida para cocinar ->
# Comino molido -> comino
# Sal -> sal
# Moras -> moras
# Azúcar -> azúcar
# Queso crema -> queso
# Leche -> leche
# Yogur griego -> yogur
# Azúcar glasé -> azúcar glasé
# Lacón de cerdo fresco -> lacón fresco
# Dientes de ajo -> dientes ajo
# Perejil fresco -> perejil fresco
# Vino blanco -> vino
# Aceite de oliva -> aceite oliva
# Pimentón dulce -> pimentón
# Orégano seco -> orégano
# Clavos -> clavos
# Sal gruesa -> sal gruesa
# Coliflor -> coliflor
# Mantequilla -> mantequilla
# Harina de trigo -> harina trigo
# Leche -> leche
# Pimienta blanca molida -> pimienta blanca
# Sal -> sal
# Queso rallado (tipo cheddar, gouda o emmental) -> queso rallado
# Salmón un lomo cortado en 4 filetes (aproximadamente) -> salmón lomo filete
# Limón (1 exprimido y el otro cortado en rodajas finas) -> limón
# Ralladura de limón media cucharada sopera -> ralladura limón
# Sal y pimienta al gusto -> sal
# Caldo de pescado o fumet -> caldo pescado
# Nata líquida para cocinar ->
# Leche evaporada -> leche evaporado leche
# Eneldo fresco muy picado, al gusto -> eneldo fresco
# Cebolla (o chalota) muy picada -> cebolla
# Diente de ajo muy picado -> ajo
# Harina de trigo media cucharada sopera -> harina trigo
# Pulpo cocido (pata envasada) -> pulpo
# Patata (unos 450-500 g) -> patata
# Aceite de oliva virgen extra -> aceite virgen
# Zumo de limón -> zumo limón
# Perejil fresco un buen manojo -> perejil fresco
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Pollo asado o cocido (aproximadamente) -> pollo
# Espinaca fresca (brotes o baby, preferiblemente) -> espinaca fresca
# Rúcula o canónigos -> rúcula canónigo
# Frambuesas -> frambuesas
# Almendra laminada al gusto -> almendra
# Queso de rulo de cabra en medallones -> queso rulo cabra medallón
# Pimiento rojo asado o de piquillo -> pimiento rojo piquillo
# Apio ->
# Aceite de oliva virgen extra -> aceite virgen
# Vinagre de Jerez o manzana -> vinagre jerez
# Zumo de lima -> zumo lima
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Plátano -> plátano
# Chocolate fondant (negro o con leche, al gusto) -> chocolate fondant
# Pistachos para decorar -> pistachos
# Kumquat (opcional) para decorar -> kumquat
# Tomate -> tomate
# Mango -> mango
# Aguacate -> aguacate aguacate
# Aceite de oliva virgen extra -> aceite virgen
# Pan de hogaza del día anterior -> pan hogaza día
# Pimiento rojo (Un trozo) -> pimiento rojo
# Pimiento verde italiano (Medio) -> pimiento verde
# Vinagre de Jerez al gusto -> vinagre jerez
# Sal al gusto -> sal
# Diente de ajo -> ajo
# Agua mineral para remojar el pan -> agua pan
# Albahaca fresca para decorar -> albahaca albahaca fresco
# Penne (pasta corta) o macarrones, etc -> penne macarrón
# Morcillo -> morcillo
# Tomate -> tomate
# Cebolla -> cebolla
# Diente de ajo -> ajo
# Pimiento verde italiano -> pimiento verde
# Pimiento rojo -> pimiento rojo
# Salsa Worcestershire al gusto -> salsa worcestershire
# Comino molido una pizca -> comino
# Sal y pimienta al gusto -> sal
# Agua -> agua
# Orégano seco al gusto -> orégano
# Queso Parmesano -> queso parmesano
# Dorada -> dorada
# Coliflor -> coliflor
# Calabacín -> calabacín
# Cebolla -> cebolla
# Vino blanco -> vino
# Sal -> sal
# Aceite de oliva virgen extra -> aceite virgen
# Huevo L -> huevo
# Azúcar -> azúcar
# Aceite de oliva virgen extra -> aceite virgen
# Leche -> leche
# Harina de repostería -> harina repostería
# Harina de maíz (no maizena) -> harina maíz
# Avellana molida -> avellana
# Canela molida -> canela
# Sal -> sal
# Levadura química -> levadura
# Crocanti de avellana al gusto -> crocanti avellana
# Conejo troceado -> conejo
# Cebolla -> cebolla
# Pimiento verde italiano -> pimiento verde
# Salsa de tomate -> salsa tomate
# Caldo de pollo -> caldo pollo
# Vino blanco -> vino
# Aceite de oliva virgen extra -> aceite virgen
# Sal y pimienta al gusto -> sal
# Diente de ajo -> ajo
# Harina de repostería (Para la masa) -> harina repostería
# Mantequilla (Para la masa) -> mantequilla
# Azúcar (Para la masa) -> azúcar
# Agua helada, 3 cucharadas (Para la masa) -> agua
# Sal , una pizca (Para la masa) -> sal
# Yema de huevo (Para la masa) -> yema huevo
# Mantequilla (Para el relleno) -> mantequilla
# Azúcar moreno (Para el relleno) -> azúcar
# Zumo de limón , 2 cucharadas (Para el relleno) -> zumo limón
# Cacahuetes tostados a la miel (Para el relleno) -> cacahuetes miel
# Plátano (Para el relleno) -> plátano
# Yema de huevo (Para pintar la tarta) -> yema huevo
# Cabrito troceado, con o sin hueso -> cabrito hueso
# Pimentón dulce o picante, una cucharada sopera para el adobo -> pimentón picante sopera adobo
# Orégano seco una cucharadita de postre para el adobo -> orégano postre adobo
# Laurel 1 hoja para el adobo -> laurel hoja adobo
# Sal y pimienta al gusto para el adobo -> sal adobo
# Aceite de oliva virgen extra para el adobo -> aceite virgen adobo
# Tomillo fresco una cucharadita de postre para el adobo -> tomillo fresco postre adobo
# Cebolla para hacer la salsa -> cebolla
# Vino blanco para el adobo -> vino adobo
# Dientes de ajo para el adobo -> dientes ajo adobo
# Comino en grano una cucharadita de postre para el adobo -> comino grano postre adobo
# Guindilla un trozo, para el adobo -> guindilla adobo
# Agua para el adobo -> agua adobo
# Sal gruesa 1 cucharada para el adobo -> sal adobo
# Sal y pimienta al gusto -> sal
# Aceite de oliva virgen extra para dorar los trozos de cabrito -> aceite virgen cabrito
# Panecillo -> panecillo
# Mantequilla -> mantequilla
# Salmón ahumado loncheado -> salmón
# Agua -> agua
# Huevo -> huevo
# Aguacate -> aguacate aguacate
# Salsa holandesa -> salsa
# Atún en aceite -> atún aceite
# Sirope de arce una cucharada sopera -> sirope sopera
# Salsa asiática de pescado una cucharada de postre -> salsa asiática pescado
# Codillo de cerdo -> codillo cerdo
# Calabacín -> calabacín
# Puerro -> puerro
# Zanahoria -> zanahoria
# Cebolleta -> cebolleta
# Salsa de tomate 4 cucharadas soperas -> salsa
# Caldo de pollo -> caldo pollo
# Champiñones -> champiñones
# Sal y pimienta al gusto -> sal
# Huevos M -> huevos
# Azúcar blanco -> azúcar
# Azúcar moreno -> azúcar
# Mantequilla -> mantequilla
# Yogur natural -> yogur
# Plátano maduro -> plátano
# Harina de trigo -> harina trigo
# Cacao en polvo puro -> cacao polvo
# Levadura química (1 sobre) -> levadura
# Entrecot de ternera (300 g aproximadamente) -> entrecot ternera
# Queso cheddar o Provolone (ambos funden muy bien) -> provolone
# Cebolla confitada 3 cucharadas soperas -> cebolla
# Pan de bocadillo (Viena) o mejor con textura de pan bombón, similar al de los perritos o hot dogs -> pan bocadillo textura pan perrito dogs
# Aceite de oliva virgen extra para la plancha -> aceite virgen plancha
# Sal y pimienta al gusto -> sal
# Harina bizcochona con levadura -> harina levadura
# Cacao en polvo -> cacao polvo
# Huevos -> huevos
# Azúcar -> azúcar
# Aceite de girasol -> aceite girasol
# Yogur natural -> yogur
# Café soluble -> café
# Masa quebrada -> masa
# Azúcar -> azúcar
# Ralladura de naranja , 1 cucharadita -> ralladura naranja
# Huevos M -> huevos
# Almendra molida , 3 cucharadas -> almendra
# Yogur griego -> yogur
# Leche -> leche
# Fresa -> fresa
# Espinaca fresca -> espinaca fresco
# Piñones un buen puñado -> piñones
# Queso de Burgos -> queso burgos
# Tallarines -> tallarines
# Nueces -> nueces
# Sal y pimienta al gusto -> sal
# Aceite de oliva virgen extra -> aceite virgen
# Queso parmesano ->
# Pistachos -> pistachos
# Mantequilla sin sal 3 cucharadas soperas -> mantequilla sal
# Huevo -> huevo
# Harina de trigo -> harina trigo
# Leche -> leche
# Azúcar -> azúcar
# Azúcar glasé para decorar -> azúcar glasé
# Frutos rojos (opcional) para decorar -> frutos rojo
# Hierbabuena (opcional) para decorar -> hierbabuena
# Sal una pizca para la mezcla -> sal mezcla
# Esencia de vainilla (opcional) unas gotas -> esencia vainilla
# Zumo de limón (de un cuarto de limón) para terminar -> zumo limón
# Melón maduro -> melón
# Azúcar -> azúcar
# Limón o lima -> limón
# Hielo picado - a gusto -> hielo
# Huevo -> huevo
# Azúcar -> azúcar
# Nata líquida -> nata
# Extracto de vainilla , 1 cucharadita -> extracto vainilla
# Harina de repostería -> harina repostería
# Frutos rojos variados -> frutos rojo
# Mantequilla para engrasar el molde -> mantequilla molde
# Azúcar glas al gusto -> azúcar gla
# Mantequilla sin sal -> mantequilla
# Harina de repostería -> harina repostería
# Sal una pizca -> sal
# Tomillo seco al gusto -> tomillo
# Huevo -> huevo
# Leche -> leche
# Pollo asado o cocido -> pollo
# Tomate (de buena calidad) -> tomate
# Queso emmental -> queso
# Orégano seco -> orégano
# Pimienta negra molida -> pimienta negro
# Aceite de oliva virgen extra -> aceite virgen
# Lentejas -> lentejas
# Laurel -> laurel
# Calabacín -> calabacín
# Zanahoria -> zanahoria
# Diente de ajo -> ajo
# Azúcar moreno (1 cucharada) -> azúcar
# Tomillo seco al gusto -> tomillo
# Naranja -> naranja
# Cebollino al gusto -> cebollino
# Brotes de alfalfa (opcional) -> brotes alfalfa
# Aceite de oliva virgen extra -> aceite virgen
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Mantequilla a temperatura ambiente -> mantequilla
# Azúcar -> azúcar
# Huevos L -> huevos
# Esencia de vainilla -> esencia vainilla
# Sal -> sal
# Levadura química -> levadura
# Harina de repostería -> harina repostería
# Leche -> leche
# Almendras enteras -> almendras
# Colorante alimentario rojo (opcional) -> rojo
# Melocotón maduro -> melocotón
# Yogur griego sin azúcar -> yogur azúcar
# Zumo de limón o lima -> zumo limón
# Leche al gusto -> leche
# Zumo de naranja al gusto (opcional) -> zumo naranja
# Menta fresca al gusto -> menta fresco
# Zumo de lima o limón (un poco menos) -> zumo lima limón
# Salsa de soja reducida en sal -> salsa soja sal
# Aceite de oliva virgen extra -> aceite virgen
# Miel -> miel
# Comino molido en cucharaditas -> comino
# Pimienta negra molida en cucharaditas -> pimienta negro
# Chile molido en cucharaditas (o pimentón picante) -> chile
# Diente de ajo grande -> ajo
# Pimiento rojo pequeño -> pimiento rojo
# Pimiento verde pequeño -> pimiento verde
# Pimiento amarillo pequeño -> pimiento amarillo
# Cebolla blanca o morada -> cebolla blanca morada
# Contramuslos de pollo deshuesados sin piel (aprox.) -> contramuslos pollo piel
# Patata -> patata
# Diente de ajo -> ajo
# Comino molido 1 cucharadita -> comino
# Pimentón dulce 1 cucharadita -> pimentón
# Orégano seco 1 cucharadita -> orégano
# Vinagre de vino blanco -> vinagre vino
# Vino blanco -> vino
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Berenjena alargadas (1 grande o dos medianas) -> berenjena
# Aceite de girasol o de oliva suave -> aceite girasol oliva
# Chile en copos (1-2 cucharaditas) -> chile copo
# Salsa Sriracha o sambal oelek o similar -> salsa sriracha sambal
# Diente de ajo pequeños muy picados -> ajo
# Cebolleta verde (tallos finos) cortada en aros finos -> cebolleta verde aro
# Salsa asiática de pescado o salsa de soja -> salsa asiática pescado soja
# Limón -> limón
# Sal (opcional) -> sal
# Cebolla -> cebolla
# Puerro -> puerro
# Calabacín -> calabacín
# Zanahoria -> zanahoria
# Patata -> patata
# Agua o caldo de verduras -> agua caldo verdura
# Mantequilla -> mantequilla
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Pulpo cocido -> pulpo
# Arroz bomba (2 cacitos) -> arroz bomba
# Cebolla pequeña -> cebolla
# Tomate pelado y troceado ->
# Pimiento verde -> pimiento verde
# Caldo de pescado o fumet 5 cacitos -> caldo pescado cacito
# Diente de ajo -> ajo
# Sal -> sal
# Aceite de oliva virgen extra -> aceite virgen
# Pimienta negra molida -> pimienta negro
# Vino blanco -> vino
# Mejillones vivos -> mejillón
# Pimentón dulce o picante, una cucharada sopera -> pimentón picante sopera
# Cebolla -> cebolla
# Diente de ajo -> ajo
# Aceite de oliva virgen extra para rehogar la cebolla, dos cucharadas -> aceite virgen cebolla
# Cayena al gusto (al menos una) -> cayena
# Vino blanco -> vino
# Harina de trigo media cucharada sopera -> harina trigo
# Masa de pizza estirada fina -> masa pizza
# Salsa de tomate casera -> salsa tomate
# Jamón de York o cocido -> jamón york
# Queso Mozzarella o Emmental rallado -> queso mozzarella emmental rallado
# Orégano seco -> orégano
# Albahaca -> albahaca
# Pimienta negra molida -> pimienta negro
# Pan de barra -> pan barra
# Cebolla dulce -> cebolla
# Mayonesa 4 cucharadas -> mayonesa
# Queso Parmesano rallado, 4 cucharadas -> queso parmesano rallado
# Pechuga de pollo cortada en medallones -> pechuga pollo medallón
# Bacon -> bacon
# Nata líquida para cocinar ->
# Champiñones -> champiñones
# Vinagre de Módena concentrado -> vinagre módena
# Sal y pimienta al gusto -> sal
# Queso Parmesano -> queso parmesano
# Pimiento rojo medianos -> pimiento rojo
# Cuscús -> cuscús
# Garbanzos -> garbanzos
# Uvas pasas -> uvas
# Calabacín -> calabacín
# Cebolla de primavera o de verdeo puñado generoso -> cebolla primavera verdeo generoso
# Sal y pimienta al gusto -> sal
# Aceite de oliva virgen extra -> aceite virgen
# Comino molido 1 cucharadita -> comino
# Agua o caldo de verduras -> agua caldo verdura
# Cebolla blanca -> cebolla blanca
# Pan rallado o panko -> pan rallado panko
# Arándanos ->
# Huevo L -> huevo
# Azúcar (y algo más para espolvorear) -> azúcar
# Leche -> leche
# Esencia de vainilla -> esencia vainilla
# Sal -> sal
# Harina de trigo -> harina trigo
# Aguardiente o licor o zumo de naranja -> aguardiente licor zumo naranja
# Ralladura de limón -> ralladura limón
# Mantequilla para engrasar -> mantequilla
# Azúcar moreno -> azúcar
# Agua -> agua
# Nata líquida para montar ->
# Huevo M -> huevo
# Leche -> leche
# Crema de whisky -> crema whisky
# Yemas de huevo -> yemas huevo
# Queso de rulo de cabra ligeramente firme -> queso rulo cabra
# Aceite de oliva virgen extra -> aceite virgen
# Hierbas provenzales 1 cucharada colmada -> hierba
# Pan rallado 1/2 vaso -> pan rallado 1/2
# Panko 2 cucharadas -> panko
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Mostaza de Dijon -> mostaza dijon
# Vinagre de Jerez -> vinagre jerez
# Rabo de toro -> rabo toro
# Diente de ajo -> ajo
# Cebolla -> cebolla
# Puerro -> puerro
# Zanahoria -> zanahoria
# Pimiento verde italiano -> pimiento verde
# Laurel hojas -> laurel hojas
# Pimienta negra en grano 10 bayas -> pimienta negro grano baya
# Clavos de olor 2 -> clavo olor
# Vino tinto 1 vaso -> vino tinto
# Caldo de carne 2  vasos -> caldo carne
# Agua 1 vaso -> agua
# Harina de trigo -> harina trigo
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Tomate -> tomate
# Clara de huevo L -> clara huevo
# Sal una pizca -> sal
# Azúcar -> azúcar
# Zumo de limón o de naranja -> zumo limón naranja
# Almendra molida (cantidad ajustable) -> almendra
# Canela molida una cucharadita colmada -> canela canela
# Cardamomo media cucharadita -> cardamomo
# Clara de huevo pasteurizada -> clara huevo
# Azúcar glasé tamizado -> azúcar glasé
# Cardamomo una pizca -> cardamomo
# Higos -> higo
# Queso azul de cabra u otro tipo -> queso cabra tipo
# Nueces -> nueces
# Miel -> miel
# Tomillo fresco o seco -> tomillo fresco
# Hinojo fresco 1 bulbo -> hinojo fresco bulbo
# Patata grande -> patata
# Cebolla -> cebolla
# Zanahoria -> zanahoria
# Caldo de verduras -> caldo verdura
# Nata líquida para cocinar ->
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Pollo de corral troceado -> pollo corral
# Dientes de ajo -> dientes ajo
# Tomate pera -> tomate
# Cerveza -> cerveza
# Aceite de oliva virgen extra -> aceite virgen
# Sal y pimienta al gusto -> sal
# Rape fresco limpio y troceado -> rape fresco
# Harina de trigo -> harina trigo
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Cabeza de ajos -> cabeza ajo
# Patatas grandes -> patatas
# Laurel -> laurel
# Tomate pelado y troceado ->
# Cebolla pelada y troceada ->
# Perejil fresco -> perejil fresco
# Almendras fritas -> almendras fritas
# Vino blanco -> vino
# Agua -> agua
# Café soluble 4 cucharadas -> café
# Azúcar 4 cucharadas -> azúcar
# Agua caliente 4 cucharadas -> agua
# Leche o bebida vegetal -> leche bebida
# Hielo -> hielo
# Costillas de cerdo -> costillas cerdo
# Azúcar moreno 6 cucharadas -> azúcar moreno
# Sal -> sal
# Salsa de soja al gusto -> salsa soja
# Cebolla morada -> cebolla morada
# Pimiento entreverado -> pimiento
# Zanahoria -> zanahoria
# Calabacín -> calabacín
# Almendras fritas -> almendras fritas
# Aceite de oliva virgen extra -> aceite virgen
# Berenjena grandes -> berenjena
# Cebolla morada o dulce -> cebolla morada
# Diente de ajo -> ajo
# Cúrcuma molida 1 y 1/2 cucharaditas -> cúrcuma
# Comino molido 1/2 cucharadita -> comino
# Yogur natural (o un poco más) -> yogur
# Pimiento verde picante o chile verde -> pimiento verde chile verde
# Lima o 1/2 limón -> lima
# Pimentón picante al gusto -> pimentón
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Aceite de oliva virgen extra -> aceite virgen
# Perejil fresco o cilantro -> perejil fresco cilantro
# Bacalao fresco o desalado (piezas de 120 g aproximadamente) -> bacalao fresco
# Patata medianas -> patata
# Dientes de ajo -> dientes ajo
# Aceite de oliva virgen extra -> aceite virgen
# Vino blanco un buen chorreón -> vino chorreón
# Sal y pimienta al gusto -> sal
# Cebolla opcional -> cebolla
# Mantequilla sin sal -> mantequilla
# Harina de repostería -> harina repostería
# Almendra molida -> almendra
# Azúcar -> azúcar
# Amaretto -> amaretto
# Levadura química 2 cucharaditas -> levadura
# Huevos -> huevos
# Acelgas -> acelgas
# Patata pequeña -> patata
# Cebolla pequeña -> cebolla
# Agua aproximadamente -> agua
# Sal y pimienta al gusto -> sal
# Aceite de oliva virgen extra para rehogar los ingredientes, aproximadamente 3 cucharadas soperas -> aceite virgen ingrediente
# Buey de mar -> buey mar
# Sal gruesa cucharadas -> sal gruesa
# Laurel hoja -> laurel hoja
# Agua -> agua
# Huevo -> huevo
# Leche -> leche
# Harina de repostería -> harina repostería
# Sal 1 pizca -> sal
# Pimentón dulce o picante, 1 pizca -> pimentón picante
# Tomillo seco o fresco al gusto -> tomillo fresco
# Cebollino al gusto (opcional) -> cebollino
# Pimienta negra molida -> pimienta negro
# Queso Provolone (o un poco más) -> queso provolone
# Jamón serrano o ibérico al gusto -> jamón
# Masa quebrada -> masa
# Huevo M -> huevo
# Yemas de huevo M -> yemas huevo
# Nata líquida para montar ->
# Azúcar -> azúcar
# Azúcar moreno -> azúcar
# Extracto de vainilla al gusto -> extracto vainilla
# Azúcar -> azúcar
# Limón 3 o 4 tiras de pieles -> limón tira piel
# Almendras tostadas picadas -> almendra tostada
# Manteca de cerdo -> manteca cerdo
# Harina de repostería -> harina repostería
# Levadura química 1 cucharadita -> levadura
# Canela molida 1/2 cucharadita -> canela canela
# Clara de huevo -> clara huevo
# Azúcar de coco 1/4 taza (para el caramelo) -> azúcar coco
# Agua 1 cucharada (para el caramelo) -> agua
# Sal una pizca (para el caramelo) -> sal
# Anacardos (puestos en remojo en agua durante 1 hora) 1/4 de taza (para el flan) ->
# Harina de garbanzo 1 cucharada (para el flan) -> harina garbanzo
# Fécula de maíz 1 cucharada colmada (para el flan) -> maíz
# Bicarbonato sódico una pizca (para el flan) -> bicarbonato sódico
# Azúcar (o edulcorante a nuestra elección) 1 cucharada (para el flan) -> azúcar
# Extracto de vainilla 2 gotas (para el flan) -> extracto vainilla
# Agua 1 taza (para el flan) -> agua
# Sal una pizca (para el flan) -> sal
# Zumo de limón 1 cucharada (para el flan) -> zumo limón
# Ralladura de limón 1 cucharadita (para el flan) -> ralladura limón
# Harina de repostería aproximadamente una medida de una lata de leche condensada -> harina repostería medida leche
# Aceite de girasol aproximadamente la mitad de una lata de leche condensada -> aceite girasol mitad leche
# Ralladura de limón (de medio limón) -> ralladura limón
# Huevos -> huevos
# Levadura química un sobre (16 g aprox) -> levadura
# Leche condensada 1 lata pequeña -> leche
# Mantequilla para engrasar las sartenes -> mantequilla sartén
# Papel de hornear para las bases de las sartenes -> papel base sartén
# Azúcar glasé para espolvorear -> azúcar glasé
# Queso gruyère -> queso gruyère
# Queso Vacherin Fribourgeois -> queso vacherin fribourgeois
# Vino blanco seco -> vino
# Diente de ajo -> ajo
# Maicena -> maicena
# Licor de cereza o kirsch -> licor cereza kirsch
# Pimienta negra molida -> pimienta negro
# Zumo de limón cucharadita -> zumo limón
# Gelatina en láminas (aprox. 1 1/2 láminas) -> gelatina lámina
# Nata líquida -> nata
# Frambuesas -> frambuesas
# Azúcar -> azúcar
# Zumo de limón -> zumo limón
# Chocolate negro 1 onza -> chocolate negro
# Patata -> patata
# Salmón fresco -> salmón fresco
# Cebolla -> cebolla
# Nata líquida para cocinar ->
# Huevo -> huevo
# Eneldo fresco un manojo -> eneldo fresco
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Huevo -> huevo
# Yogur griego -> yogur
# Harina de repostería -> harina repostería
# Azúcar -> azúcar
# Aceite de girasol -> aceite girasol
# Levadura química -> levadura
# Miga de pan integral (Para las migas) -> miga pan integral
# Azúcar moreno (Para las migas) -> azúcar
# Avellanas tostadas (Para las migas) -> avellana
# Canela molida al gusto (Para las migas) -> canela canela
# Manzana (Para el puré de manzana) -> manzana
# Miel , 2 cucharadas (Para el puré de manzana) -> miel
# Azúcar , 1 cucharada (Para el puré de manzana) -> azúcar
# Ralladura de limón (Para el puré de manzana) -> ralladura limón
# Zumo de limón de una pieza (Para el puré de manzana) -> zumo limón
# Nata líquida para montar (Para adornar) ->
# Mantequilla sin sal -> mantequilla
# Leche -> leche
# Ralladura de limón 1 cucharada -> ralladura limón
# Ralladura de naranja 1 cucharada -> ralladura naranja
# Azúcar (150 si se prefieren más dulces) -> azúcar
# Harina de trigo de todo uso -> harina trigo uso
# Levadura química -> levadura
# Sal -> sal
# Huevo L -> huevo
# Yema de huevo L -> yema huevo
# Esencia de vainilla (opcional) -> esencia vainilla
# Pan integral en rebanadas (o de cereales) -> pan integral rebanada
# Alcachofa en conserva o naturales y cocidas -> alcachofa conserva
# Bacalao ahumado (aproximadamente) -> bacalao
# Pimiento rojo asado o varios piquillos -> pimiento rojo piquillo
# Queso de rulo de cabra -> queso rulo cabra
# Albahaca unas hojas frescas -> albahaca hoja fresco
# Pimienta negra molida -> pimienta negro
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Espinaca fresca (mejor si son brotes o baby) lavada -> espinaca fresca
# Dátiles -> dátiles
# Queso parmesano ->
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Queso mascarpone -> queso
# Yema de huevo -> yema huevo
# Clara de huevo -> clara huevo
# Nata líquida para montar ->
# Azúcar glasé -> azúcar glasé
# Agua caliente -> agua
# Café soluble 2 cucharaditas -> café
# Sal -> sal
# Cacao en polvo -> cacao polvo
# Galletas tipo Digestive -> galletas tipo digestive
# Mantequilla derretida -> mantequilla
# Queso crema a temperatura ambiente -> queso crema
# Nata líquida para montar a temperatura ambiente ->
# Huevo a temperatura ambiente -> huevo
# Azúcar -> azúcar
# Ralladura de limón o lima (opcional) -> ralladura limón lima
# Frambuesas al gusto -> frambuesas
# Contramuslos de pollo sin piel y sin hueso -> contramuslo pollo piel hueso
# Garbanzos cocidos -> garbanzo
# Pimiento rojo -> pimiento rojo
# Pimiento verde -> pimiento verde
# Cebolleta -> cebolleta
# Diente de ajo -> ajo
# Pimentón dulce 1 y 1/2 cucharaditas -> pimentón
# Pimentón picante 1/2 cucharadita -> pimentón
# Comino molido 1/2 cucharadita -> comino
# Tomate troceado natural ->
# Caldo de pollo o verduras o agua -> caldo pollo verdura agua
# Espinaca fresca un manojo -> espinaca fresca
# Nata líquida para cocinar ->
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Aceite de oliva virgen extra -> aceite virgen
# Cebolla -> cebolla
# Diente de ajo -> ajo
# Cayena -> cayena
# Pimentón picante -> pimentón
# Tomate natural triturado -> tomate
# Caldo de verduras , pollo o carne -> caldo verdura pollo carne
# Vinagre de Jerez -> vinagre jerez
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Azúcar (opcional) -> azúcar
# Aceite de oliva virgen extra -> aceite virgen
# Patata -> patata
# Aceite de oliva virgen extra o de girasol -> aceite virgen girasol
# Mantequilla una cucharada -> mantequilla
# Cúrcuma molida 1/4 de cucharadita de postre -> cúrcuma
# Chile molido 1/4 de cucharadita de postre -> chile
# Comino molido o en grano 1/4 de cucharadita de postre -> comino grano
# Cilantro molido 1/4 de cucharadita de postre -> cilantro
# Pimienta negra molida 1/4 de cucharadita de postre -> pimienta negro
# Sal al gusto -> sal
# Mango deshidratado en polvo o amchoor, (puedes omitirlo si no tienes), 1/4 de cucharadita de postre -> mango polvo
# Judías verdes redondas o planas -> judías verde plana
# Zanahoria -> zanahoria
# Cebolla -> cebolla
# Apio penca -> penca
# Sal -> sal
# Tomate pera -> tomate
# Alcaparras -> alcaparras
# Laurel -> laurel
# Queso Parmesano rallado -> queso parmesano rallado
# Mozzarella fresca -> mozzarella fresco
# Orégano seco -> orégano
# Pimienta negra molida -> pimienta negro
# Vino blanco -> vino
# Judías verdes redondas o planas -> judías verde plana
# Tomate cherry -> tomate
# Rabanitos -> rabanitos
# Pimiento rojo asado -> pimiento rojo
# Rúcula -> rúcula
# Queso de cabra semicurado -> queso cabra
# Anchoas lata pequeña -> anchoas
# Almendras laminadas o piñones -> almendra piñón
# Aceitunas negras -> aceituna negro
# Ralladura de limón al gusto -> ralladura limón
# Aceite de oliva virgen extra -> aceite virgen
# Vinagre de Jerez o manzana -> vinagre jerez
# Pimienta negra molida al gusto -> pimienta negro
# Sal al gusto -> sal
# Hierbas provenzales al gusto -> hierba
# Agua -> agua
# Levadura prensada fresca -> levadura fresco
# Harina de fuerza -> harina fuerza
# Sal -> sal
# Berenjena -> berenjena
# Pimiento verde italiano -> pimiento verde
# Pimiento rojo -> pimiento rojo
# Cebolla -> cebolla
# Tomate maduro -> tomate
# Aceite de oliva virgen extra -> aceite virgen
# Aceitunas rellenas -> aceituna
# Pan de hogaza grande de pan asentado -> pan hogaza pan
# Cabeza de ajos -> cabeza ajo
# Pimiento rojo -> pimiento rojo
# Sardinas frescas -> sardinas fresco
# Aceite de oliva virgen extra -> aceite virgen
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Tomate para servir -> tomate
# Huevo -> huevo
# Patata -> patata
# Pimiento verde italiano -> pimiento verde
# Pimientos de color verde y rojo, un trozo de cada -> pimiento color verde rojo
# Cebolla -> cebolla
# Chile jalapeño en rodajas -> chile rodaja
# Chorizo fresco u oreado -> fresco
# Aceite de oliva virgen extra para freír las patatas y los pimientos -> aceite virgen patata pimiento
# Cilantro fresco para decorar -> cilantro fresco
# Arroz basmati (opcional) de guarnición -> arroz basmati guarnición
# Cebolla -> cebolla
# Zanahoria -> zanahoria
# Arroz redondo -> arroz
# Caldo de verduras -> caldo verdura
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Puré de calabaza -> puré calabaza
# Huevos talla L -> huevos
# Almendra molida -> almendra
# Harina de trigo -> harina trigo
# Aceite de girasol -> aceite girasol
# Azúcar moreno -> azúcar
# Baking Powder Royal -> baking powder royal
# Mezcla de especias de pan de especias , 1 cucharadita -> mezcla especia pan especia
# Azúcar glas (Para la crema de queso) -> gla
# Mantequilla a Tª ambiente (Para la crema de queso) -> mantequilla tª
# Queso crema (Para la crema de queso) -> queso crema
# Clara de huevo a temperatura ambiente -> clara huevo
# Nata líquida para montar muy fría ->
# Azúcar -> azúcar
# Harina de trigo -> harina trigo
# Atún fresco -> atún fresco
# Pimiento verde -> pimiento verde
# Pimiento amarillo -> pimiento amarillo
# Pimientos del piquillo -> pimiento piquillo
# Morcillo -> morcillo
# Cebolla morada cortadas en juliana -> cebolla juliana
# Vino de Jerez -> vino jerez
# Caldo de carne -> caldo carne
# Aceite de oliva virgen extra -> aceite virgen
# Sal y pimienta al gusto -> sal
# Tomate cherry -> tomate
# Aceite de oliva virgen extra -> aceite virgen
# Comino en grano 3/4 cucharadita -> comino grano
# Azúcar moreno 1 cucharadita -> azúcar moreno
# Diente de ajo -> ajo
# Tomillo fresco (ramitas) -> tomillo fresco
# Orégano fresco (ramitas) -> orégano fresco
# Limón -> limón
# Yogur griego -> yogur
# Chile en copos 1 cucharadita -> chile copo
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Fresa -> fresa
# Naranja de zumo -> naranja zumo
# Azúcar 4 cucharadas -> azúcar
# Huevo para el curd -> huevo curd
# Azúcar para el curd -> azúcar curd
# Zumo de naranja para el curd -> zumo naranja curd
# Mantequilla para el curd -> mantequilla curd
# Ralladura de naranja para el curd -> ralladura naranja curd
# Tulipas para helado (de galleta) -> tulipas helado
# Menta fresca para decorar -> menta fresco
# Salmón fresco en un lomo -> salmón fresco
# Patata -> patata
# Cebolleta -> cebolleta
# Diente de ajo -> ajo
# Eneldo fresco (o seco si no tienes), unas ramitas -> eneldo fresco
# Vino blanco un chorrito -> vino
# Sal y pimienta al gusto -> sal
# Naranja -> naranja
# Canela en rama -> canela canela rama
# Lechuga iceberg -> lechuga iceberg
# Queso feta -> queso
# Rabanitos -> rabanitos
# Cebolla -> cebolla
# Mayonesa 1/2 taza -> mayonesa
# Vinagre de Jerez -> vinagre jerez
# Zumo de limón -> zumo limón
# Salsa Tabasco unas gotas -> salsa tabasco
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Atún en aceite -> atún aceite
# Salsa de tomate -> salsa tomate
# Huevo -> huevo
# Pan rallado (opcional) -> pan rallado
# Láminas de pasta para canelones -> láminas pasta canelón
# Sal -> sal
# Pimienta blanca molida -> pimienta blanca
# Aceite de oliva virgen extra -> aceite virgen
# Queso rallado tipo Cheddar -> queso rallado tipo cheddar
# Salsa bechamel -> salsa bechamel
# Calabaza pelada -> calabaza
# Dientes de ajo pelados y picados -> dientes ajo
# Perejil fresco picado un manojo -> perejil fresco
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Almendras -> almendras
# Nueces pacanas -> nueces
# Kale (hojas) limpio y troceado -> kale
# Huevo -> huevo
# Clara de huevo -> clara huevo
# Nata líquida para cocinar o leche -> leche
# Mostaza de Dijon -> mostaza dijon
# Cúrcuma molida 1/2 cucharadita -> cúrcuma
# Tomillo fresco 2 ramitas o 1 cucharadita seco -> tomillo fresco
# Higos -> higo
# Queso de cabra -> queso cabra
# Perejil fresco -> perejil fresco
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Aceite de oliva virgen extra -> aceite virgen
# Fabas asturianas -> fabas
# Chorizo asturiano -> chorizo
# ...
# Cebolla blanca -> cebolla blanca
# Jamón serrano loncheado -> jamón
# Queso crema -> queso
# Salsa de tomate -> salsa tomate
# Queso rallado -> queso rallado
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Queso Idiazábal -> queso idiazábal
# Nata líquida para cocinar ->
# Mantequilla -> mantequilla
# Hongos boletus o cualquier variedad de hongos para guarnición (opcional) -> hongos boletus variedad hongo guarnición
# Cebollitas francesas -> cebollitas
# Aceite de oliva virgen extra -> aceite virgen
# Ajo granulado 1 cucharadita -> ajo
# Sal y pimienta al gusto -> sal
# Hierbas provenzales 1 cucharadita -> hierba
# Mantequilla a Tª ambiente -> mantequilla tª
# Azúcar -> azúcar
# Harina de repostería -> harina repostería
# Leche a Tª ambiente -> leche tª
# Levadura química -> levadura
# Esencia de vainilla -> esencia vainilla
# Fondant blanco -> fondant
# Ojos de azúcar -> ojos azúcar
# Levadura fresca de panadería (esponja) -> levadura fresca panadería
# Azúcar (esponja) -> azúcar
# Leche a temperatura ambiente (esponja) -> leche
# Harina de fuerza (esponja) -> harina fuerza
# Harina de fuerza -> harina fuerza
# Azúcar -> azúcar
# Huevo M a temperatura ambiente -> huevo
# Leche a temperatura ambiente -> leche
# Sal -> sal
# Mantequilla a temperatura ambiente -> mantequilla
# Nueces picadas -> nuez
# Uvas pasas sultanas -> uvas pasa
# Ron -> ron
# Almendras -> almendras
# Azúcar glasé -> azúcar glasé
# Harina de repostería -> harina repostería
# Cacao en polvo -> cacao polvo
# Levadura química media cucharadita -> levadura
# Sal una pizca -> sal
# Azúcar -> azúcar
# Ralladura de naranja -> ralladura naranja
# Canela molida media cucharadita -> canela canela
# Jengibre molido una pizca -> jengibre
# Nuez moscada molida una pizca -> nuez
# Mazapán picado -> mazapán
# Mantequilla sin sal -> mantequilla
# Huevo L -> huevo
# Volován unidades -> volován
# Calabacín mediano -> calabacín
# Cebolla blanca grande -> cebolla blanca
# Huevo L -> huevo
# Sal y pimienta al gusto -> sal
# Aceite de oliva virgen extra -> aceite virgen
# Mollejas de ternera -> mollejas ternera
# Tocino -> tocino
# Cebolla media -> cebolla
# Zanahoria media -> zanahoria
# Caldo de carne -> caldo carne
# Vino de Jerez -> vino jerez
# Setas variadas -> seta
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Aceite de oliva virgen extra -> aceite virgen
# Redondo de ternera -> redondo ternera
# Cebolla -> cebolla
# Puerro -> puerro
# Apio ->
# Perejil (ramita) -> perejil
# Laurel -> laurel
# Zanahoria -> zanahoria
# Vino blanco -> vino
# Huevo L muy fresco -> huevo fresco
# Aceite de oliva virgen extra suave o de girasol -> aceite virgen girasol
# Atún en aceite escurrido -> atún aceite
# Alcaparras -> alcaparras
# Anchoas -> anchoas
# Zumo de limón -> zumo limón
# Atún fresco limpio (o congelado) -> atún fresco
# Yema de huevo -> yema huevo
# Jengibre fresco 1 trocito pelado -> jengibre fresco trocito
# Harissa (u otra salsa picante, ajustar según tolerancia) -> harissa
# Zumo de limón -> zumo limón
# Cilantro fresco o perejil, 1 cucharadita picado -> cilantro fresco perejil
# Tomillo fresco 1 cucharadita -> tomillo fresco
# Salsa de soja -> salsa soja
# Ajo granulado una pizca -> ajo
# Aceite de oliva virgen extra -> aceite virgen
# Pimienta negra molida -> pimienta negro
# Panecillo -> panecillo
# Escarola -> escarola
# Tomate pera o de rama -> tomate rama
# Queso fresco batido desnatado o yogur natural -> fresco yogur
# Harissa una pizca para la salsa ->
# Tomillo fresco extra para la salsa -> tomillo fresco
# Cebolla dulce -> cebolla
# Pimiento rojo mediano -> pimiento rojo
# Diente de ajo -> ajo
# Berenjena grande -> berenjena
# Tomate triturado -> tomate
# Tomate concentrado ->
# Caldo de verduras o agua -> caldo verdura agua
# Cilantro en grano cucharada (opcional) -> cilantro grano
# Cilantro fresco o perejil -> cilantro fresco perejil
# Eneldo fresco (opcional) -> eneldo fresco
# Aceite de oliva virgen extra -> aceite virgen
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Huevo (para el bizcocho) -> huevo
# Miel (para el bizcocho) -> miel
# Agua (para el bizcocho) -> agua
# Harina de trigo (para el bizcocho) -> harina trigo
# Trisol (para el bizcocho) -> trisol
# Azúcar (para el bizcocho) -> azúcar
# Carga de sifón (para el bizcocho) -> carga sifón
# Coliflor (para la crema de coliflor) -> coliflor
# Leche (para la crema de coliflor) -> leche
# Nata líquida (para la crema de coliflor) -> nata
# Mantequilla (para la crema de coliflor) -> mantequilla
# Pectina en polvo (para la crema de coliflor) -> pectina polvo
# Azúcar (para la crema de coliflor) -> azúcar
# Cabeza de ajos -> cabeza ajo
# Guindilla -> guindilla
# Aceite de oliva virgen extra -> aceite virgen
# Yema de huevo -> yema huevo
# Azúcar -> azúcar
# Salmonete -> salmonete
# Txakolí -> txakolí
# Vinagre de manzana -> vinagre manzana
# Chicharro (lomos de unos 300 g) -> chicharro
# Sal -> sal
# Azúcar -> azúcar
# Perlas de aceite de oliva aromatizado con romero -> perlas aceite oliva romero
# Quinoa -> quinoa
# Arroz redondo deshidratado y frito -> arroz
# Brotes de apio u hojas -> brotes apio hoja
# Fresa de gran tamaño (o fresón) -> fresa tamaño
# Piñones (un buen puñado) -> piñones
# Aceite de oliva virgen extra -> aceite virgen
# Vinagre de Módena de buena calidad, al gusto -> vinagre módena calidad
# Sal maldón o sal en escamas -> sal maldón escama
# Agua (para el té) -> agua
# Té negro , 2 cucharaditas -> té negro
# Nueces troceadas -> nuez
# Huevos -> huevos
# Azúcar -> azúcar
# Aceite de girasol -> aceite girasol
# Azúcar aromatizado con vainilla, 2 cucharadas -> azúcar vainilla
# Cacao puro en polvo , 3 cucharadas -> cacao polvo
# Zumo de limón , 1/2 cucharadita -> zumo limón
# Harina -> harina
# Levadura química , 1 sobre -> levadura
# Mantequilla a temperatura ambiente (para la masa) -> mantequilla
# Sal (para la masa) -> sal
# Azúcar glasé (para la masa) -> azúcar glasé
# Almendra molida (para la masa) -> almendra
# Huevos L (para la masa) -> huevos
# Harina de repostería (para la masa) -> harina repostería
# Mantequilla a temperatura ambiente (para la crema de almendra) -> mantequilla
# Almendra molida (para la crema de almendra) -> almendra
# Azúcar glasé (para la crema de almendra) -> azúcar glasé
# Huevos L (para la crema de almendra)(para la crema de almendra) -> huevos
# Harina de maíz refinada (para la crema de almendra) -> harina maíz
# Nata líquida para cocinar (para la crema de almendra) ->
# Ron moreno (para la crema de almendra) -> ron moreno
# Agua (para las peras pochadas) -> agua
# Azúcar (para las peras pochadas) -> azúcar
# Vainilla (para las peras pochadas) -> vainilla
# Pera conferencia (para las peras pochadas) -> pera conferencia
# Almendra laminada al gusto (para decorar) -> almendra
# Azúcar glasé al gusto (para decorar) -> azúcar glasé
# Patata -> patata
# Aceite de oliva virgen extra cucharadas -> aceite virgen
# Pimiento rojo -> pimiento rojo
# Cebolleta -> cebolleta
# Pimiento largo picante -> pimiento
# Huevo campero -> huevo
# Aguacate grande -> aguacate aguacate
# Zumo de lima cucharadas -> zumo lima
# Cilantro fresco al gusto -> cilantro fresco
# Sal y pimienta al gusto -> sal
# Tomate maduro -> tomate
# Ciruelas rojas -> ciruela rojo
# Diente de ajo -> ajo
# Pan de hogaza seco -> pan hogaza
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Alcachofa -> alcachofa
# Huevo de codorniz -> huevo codorniz
# Queso parmesano rallado, al gusto -> queso rallado
# Sal y pimienta al gusto -> sal
# Aceite de oliva virgen extra un chorrito -> aceite virgen
# Perejil o cilantro para decorar -> perejil cilantro
# Azúcar glasé -> azúcar glasé
# Mantequilla con sal atemperada -> mantequilla sal
# Agua -> agua
# Harina de repostería -> harina repostería
# Levadura química -> levadura
# Esencia de vainilla -> esencia vainilla
# Fresa limpias y sin pedúnculo -> fresa pedúnculo
# Mantequilla atemperada -> mantequilla
# Azúcar glasé -> azúcar glasé
# Pulpo cocido 4 patas o tentáculos -> pulpo pata tentáculo
# Aceite de oliva virgen extra 6 cucharadas -> aceite virgen
# Guindilla -> guindilla
# Diente de ajo muy picado (medio) -> ajo
# Sal maldón unos cristalitos -> sal maldón cristalito
# Huevo -> huevo
# Azúcar -> azúcar
# Chocolate negro -> chocolate negro
# Crema de castañas -> crema castaña
# Mantequilla -> mantequilla
# Maizena -> maizena
# Sal una pizca -> sal
# Cuartos traseros de pollo -> cuarto pollo
# Dientes de ajo -> dientes ajo
# Limón -> limón
# Mantequilla -> mantequilla
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Romero fresco ramitas -> romero fresco
# Aguardiente o licor -> aguardiente licor
# Albahaca al gusto -> albahaca
# Romero fresco al gusto -> romero fresco
# Menta fresca al gusto -> menta fresco
# Tomillo fresco al gusto -> tomillo fresco
# Hierbabuena al gusto -> hierbabuena
# Clavo de olor al gusto -> clavo olor
# Canela en rama al gusto -> canela canela rama
# Bayas de enebro al gusto -> bayas enebro
# Azúcar -> azúcar
# Agua -> agua
# Harina de fuerza -> harina fuerza
# Huevo M -> huevo
# Leche templada -> leche
# Queso mascarpone -> queso
# Azúcar molido -> azúcar
# Levadura fresca de panadería -> levadura fresca panadería
# Sal una pizca -> sal
# Azúcar molido para espolvorear -> azúcar
# Huevo batido para pincelar la masa -> huevo masa
# Ternera para estofar, cortada en tacos -> ternera taco
# Cebolla -> cebolla
# Diente de ajo -> ajo
# Laurel -> laurel
# Tomate triturado en conserva -> conserva
# Vino fino Montilla-Moriles -> vino montilla moriles
# Nuez moscada molida -> nuez
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Yema de huevo -> yema huevo
# Nata líquida -> nata
# Leche condensada -> leche
# Leche entera -> leche
# Esencia de vainilla 1 cucharadita -> esencia vainilla
# Galletas Oreo -> galletas oreo
# Patata mediana -> patata
# Alcachofa en conserva -> alcachofa conserva
# Huevo -> huevo
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Mayonesa 4 cucharadas -> mayonesa
# Yogur griego 4 cucharadas -> yogur
# Aceite de oliva virgen extra -> aceite virgen
# Plátano grande -> plátano
# Dátiles sin hueso -> dátiles hueso
# Copos de avena -> copo avena
# Leche de almendras -> leche almendra
# Pepitas de chocolate o chocolate rallado sin azúcar -> pepitas chocolate chocolate rallado azúcar
# Canela molida una pizca -> canela canela
# Alubias pintas secas -> pinta
# Cebolla -> cebolla
# Ajos ->
# Zanahoria grande -> zanahoria
# Judías verdes redondas bobby -> judías verde bobby
# Nabo mediano -> nabo
# Calabacín mediano -> calabacín
# Apio ->
# Tomate grande y maduro -> tomate
# Pasta corta seca -> pasta
# Hierbas provenzales al gusto -> hierba
# Caldo de verduras necesario (o agua) -> caldo verdura
# Queso Parmesano o grana padano (opcional) -> queso parmesano grana
# Aceite de oliva virgen extra -> aceite virgen
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Patata medianas -> patata
# Guisantes -> guisantes
# Alcachofa corazones en conserva -> alcachofa corazón conserva
# Cebolla blanca pequeña -> cebolla blanca
# Perejil fresco o cilantro -> perejil fresco cilantro
# Sal y pimienta al gusto -> sal
# Aceite de oliva virgen extra para dorar las verduras -> aceite virgen verdura
# Semillas de mostaza -> semillas mostaza
# Vinagre de vino blanco -> vinagre vino
# Vinagre de vino blanco seco o de sidra -> vinagre vino sidra
# Sirope de arce o miel -> sirope arce miel
# Cúrcuma molida 1 cucharadita -> cúrcuma
# Sal 1/2 cucharadita -> sal
# Salsa Worcestershire -> salsa worcestershire
# Huevo -> huevo
# Azúcar -> azúcar
# Mantequilla a temperatura ambiente -> mantequilla
# Nesquik -> nesquik
# Vino tinto -> vino tinto
# Harina de repostería -> harina repostería
# Levadura química -> levadura
# Sal un pellizco -> sal
# Atún fresco en filetes -> atún fresco filete
# Limón o lima -> limón
# Ajo granulado -> ajo
# Salsa de soja -> salsa soja
# Fideos noodles de huevo -> fideos huevo
# Cebolleta -> cebolleta
# Jengibre fresco un trocito -> jengibre fresco trocito
# Guindilla pequeña (opcional) -> guindilla
# Pimientos de color pequeños -> pimiento color
# Vino blanco o mirin -> vino
# Miso blanco -> miso
# Caldo de verduras o pescado -> caldo verdura
# Espinaca fresca un buen manojo -> espinaca fresca
# Pimienta negra molida -> pimienta negro
# Sal -> sal
# Aceite de oliva virgen extra -> aceite virgen
# Mejillones -> mejillones
# Aceite de oliva virgen extra , 4 cucharadas -> aceite virgen
# Diente de ajo -> ajo
# Perejil picado, 3 cucharadas -> perejil
# Vino blanco -> vino
# Pimienta negra en grano al gusto -> pimienta negro grano
# Pimiento rojo , 4 trozos -> pimiento rojo
# Plátano maduro -> plátano
# Huevo L -> huevo
# Azúcar moreno -> azúcar
# Mantequilla -> mantequilla
# Harina integral -> harina integral
# Levadura química (1 cucharadita) -> levadura
# Sal 1/2 cucharadita -> sal
# Canela molida 3/4 cucharadita -> canela canela
# Esencia de vainilla 1/2 cucharadita -> esencia vainilla
# Azúcar moreno extra para cubrir -> azúcar
# Canela molida extra para cubrir -> canela canela
# Clara de huevo -> clara huevo
# Azúcar -> azúcar
# Almendra molida -> almendra
# Sal 1 pizca -> sal
# Agua de azahar -> agua
# Cardamomo (molido) 1/4 cucharadita -> cardamomo
# Almendras o pistachos para decorar -> almendras pistacho
# Naranja -> naranja
# Chocolate negro picado -> chocolate negro
# Crème fraîche -> crème
# Leche entera -> leche
# Yema de huevo -> yema huevo
# Azúcar -> azúcar
# Sal -> sal
# Aceite de oliva virgen extra -> aceite virgen
# Sal -> sal
# Crocanti de almendras -> crocanti almendra
# Harina bizcochona con levadura -> harina levadura
# Azúcar -> azúcar
# Dulce de leche -> dulce leche
# Mantequilla -> mantequilla
# Huevo L -> huevo
# Crème fraîche -> crème
# Manzana -> manzana
# Uvas pasas sultanas -> uvas pasa
# Azúcar moreno -> azúcar
# Canela en rama -> canela canela rama
# Mantequilla -> mantequilla
# Zumo de limón -> zumo limón
# Queso crema -> queso
# Masa filo láminas -> masa filo lámina
# Mantequilla -> mantequilla
# Miel 1 taza -> miel
# Bicarbonato sódico 1 cucharadita -> bicarbonato sódico
# Harina de trigo 2 tazas -> harina trigo
# Azúcar 1/2 taza -> azúcar
# Aceite de oliva virgen extra -> aceite virgen
# Piel de naranja -> piel naranja
# Zumo de naranja -> zumo naranja
# Anís dulce -> anís
# Harina de repostería -> harina repostería
# Levadura química -> levadura
# Azúcar -> azúcar
# Anís en grano 1-2 cucharaditas -> anís grano
# Piñones 1-2 cucharaditas (opcional) -> piñones
# Huevo batido -> huevo
# Azúcar para espolvorear -> azúcar
# Leche -> leche
# Huevo -> huevo
# Azúcar -> azúcar
# Esencia de vainilla 1/2 cucharadita -> esencia vainilla
# Huevo para rebozar -> huevo
# Azúcar para rebozar -> azúcar
# Canela molida para rebozar -> canela canela
# Aceite de girasol para freír -> aceite girasol
# Pan para torrijas rebanado -> pan torrija
# Coliflor -> coliflor
# Leche -> leche
# Huevo -> huevo
# Queso emmental o similar, rallado -> queso rallado
# Pimienta negra molida al gusto -> pimienta negro
# Orégano seco al gusto -> orégano
# Sal al gusto -> sal
# Leche -> leche
# Arroz redondo sobrante -> arroz
# Canela molida -> canela
# Ralladura de naranja -> ralladura naranja
# Ralladura de limón -> ralladura limón
# Azúcar -> azúcar
# Té matcha -> té matcha
# Esencia de vainilla opcional -> esencia vainilla
# Frutos secos opcional y a gusto -> frutos
# Huevo -> huevo
# Azúcar -> azúcar
# Azúcar vainillado o 1 sobre (aproximadamente) -> azúcar
# Harina de repostería -> harina repostería
# Maizena -> maizena
# Levadura química 1/4 cucharadita -> levadura
# Azúcar glasé -> azúcar glasé
# Colorante alimentario 2 gotas rosa o 1 gota rojo -> rosa rojo
# Lomo de cerdo -> lomo cerdo
# Cabeza de ajos -> cabeza ajo
# Laurel hojas -> laurel hojas
# Vinagre de sidra 1/2 vaso -> vinagre sidra
# Aceite de oliva virgen extra 1 vaso -> aceite virgen extra
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Pan tostado rodajas -> pan rodaja
# Alubias blancas -> alubias
# Tomate cherry unidades -> tomate
# Perejil seco - a gusto -> perejil
# Levadura nutricional 2 a 3 cucharadas -> levadura
# Tomillo seco -> tomillo
# Aceite de oliva virgen extra para cocinar las verduras -> aceite virgen verdura
# Sal y pimienta al gusto -> sal
# Curry molido -> curry
# Agua -> agua
# Huevos "M" -> huevo
# Patatas grandes -> patatas
# Tomate de ensalada -> tomate
# Pimiento verde italiano -> pimiento verde
# Cebolla blanca -> cebolla blanca
# Pepino español -> pepino
# Aceitunas verdes -> aceitunas verde
# Aceite de oliva virgen extra -> aceite virgen
# Vinagre de manzana -> vinagre manzana
# Agua -> agua
# Sal -> sal
# Pimienta negra molida -> pimienta negro
# Sal de aceitunas negras (opcional) -> sal aceituna negro

# %%
for i in nlp_es("Canela molida"):
    print(f"{i.text}->{i.pos_}")
# Out:
# Canela->VERB
# molida->ADJ

# %%
pd.DataFrame(clean_ing_lista).value_counts().head(60)
# Out:
# 0
# sal                   386
# aceite virgen         240
# azúcar                207
# pimienta negro        164
# huevo                 149
# ajo                   126
# mantequilla           121
# cebolla               108
#                       105
# leche                  92
# agua                   81
# harina trigo           73
# tomate                 73
# levadura               68
# zumo limón             59
# vino                   53
# pimentón               48
# harina repostería      45
# queso                  44
# pimiento verde         42
# zanahoria              42
# huevos                 40
# patata                 37
# esencia vainilla       36
# miel                   35
# cebolleta              33
# aceite girasol         33
# ralladura limón        32
# orégano                31
# pimiento rojo          30
# canela canela          29
# comino                 29
# perejil fresco         29
# almendra               28
# calabacín              27
# azúcar glasé           27
# limón                  27
# nuez                   25
# ralladura naranja      25
# dientes ajo            24
# salsa soja             24
# tomillo fresco         23
# yogur                  23
# yema huevo             23
# clara huevo            22
# pechuga pollo          21
# nata                   19
# cacao polvo            19
# bicarbonato sódico     19
# perejil                18
# harina fuerza          18
# aceite oliva           18
# salsa tomate           17
# mayonesa               17
# berenjena              16
# laurel                 16
# caldo verdura          16
# aguacate aguacate      16
# cebolla morada         16
# plátano                15
# Name: count, dtype: int64

# %%
set(clean_ing_lista)
# Out:
# {'',
#  'sardinilla parrocha aceite',
#  'romero',
#  'clavo',
#  'laurel',
#  'ali oli',
#  'endibias',
#  'tocino ternilla',
#  'panecillo',
#  'carga sifón',
#  'pan día',
#  'jamón york taquito',
#  'aceitunas verde hueso generoso',
#  'harina trigo mezcla',
#  'melocotón',
#  'salmón',
#  'yogur',
#  'amaretto licor',
#  'salsa',
#  'caracoles',
#  'aguacate aguacate tira',
#  'caramelo',
#  'cebolla',
#  'salmón lomo filete',
#  'papada cerdo piel',
#  'mejillón escabeche',
#  'vino vino',
#  'pan hogaza torrija rebanada',
#  'ajo marinada',
#  'berberechos fresco',
#  'lacón fresco',
#  'canela canela',
#  'ralladura postre tartar',
#  'bacon',
#  'cerdo',
#  'lima tira piel',
#  'bacon loncha',
#  'muslo pollo piel hueso',
#  'pan molde rebanada',
#  'chile pasta tartar',
#  'boniato',
#  'maizena',
#  'melón',
#  'hojas menta fresco',
#  'salchichas fresco',
#  'salmón crudo tira corta',
#  'copo coco',
#  'fraiche crema fresco',
#  'tortas',
#  'indicación',
#  'azúcar vainilla',
#  'arándano fresco congelado',
#  'guindilla',
#  'mermelada frambuesa cereza',
#  'vacío',
#  'zumo limón',
#  'arroz',
#  'seta',
#  'azúcar gla',
#  'crema whisky',
#  'jengibre',
#  'rape fresco cola',
#  'aceituna negro',
#  'ralladura naranja curd',
#  'crème fraîche nata fresco semi',
#  'pimentón picante sopera',
#  'especias clavos bayas pimienta negro',
#  'menta fresca rama',
#  'pan hogaza',
#  'escamas pimentón',
#  'vaina vainilla',
#  'tomate casero',
#  'provolone',
#  'sal masa mollete',
#  'cilantro 1/2',
#  'fideos',
#  'entrecot ternera',
#  'bulgur',
#  'puré calabaza casero',
#  'mantequilla mezcla',
#  'habichuela',
#  'agua masa madre',
#  'zumo limón caramelo',
#  'naranja',
#  'café',
#  'hígado conejo',
#  'acelgas',
#  'agua seta',
#  'albahaca albahaca fresca',
#  'dorada',
#  'espárrago verde',
#  'cubito hielo',
#  'arroz bomba',
#  'pechuga pollo',
#  'aceite virgen cabrito',
#  'guindilla verde fresca jalapeño acompañamiento',
#  'harina trigo masa madre mollete',
#  'melaza miel caña',
#  'cuarto pollo',
#  'anchoas',
#  'leche arroz',
#  'canela',
#  'patata tipo baby',
#  'tira',
#  'marrajo filete',
#  'zumo naranja',
#  'agua masa mollete',
#  'cebolleta parte verde',
#  'tomate',
#  'masa pasta',
#  'aceite virgen',
#  'carne cerdo magra',
#  'frutos rojo fresco',
#  'té negro',
#  'harina fuerza masa madre levadura',
#  'aceite coco estado',
#  'hoja',
#  'orejones tierno',
#  'zanahoria baby',
#  'leche coco ml',
#  'caldo pescado morralla',
#  'manzana rallado piel',
#  'canela canela vainilla',
#  'pan integral rebanada',
#  'queso parmesano rallado',
#  'pimentón picante',
#  'canónigos',
#  'cebolla blanca cebolleta',
#  'fondant',
#  'harina integral centeno',
#  'bayas enebro',
#  'queso mozzarella queso feta',
#  'frutos',
#  'cebolleta rojo',
#  'mandarina',
#  'tomates conserva',
#  'paletilla cerdo hueso kg',
#  'judía verde',
#  'jengibre fresco',
#  'eneldo fresco',
#  'harina fuerza masa mollete',
#  'caldo verdura pollo carne',
#  'pan bocadillo textura pan perrito dogs',
#  'aceite virgen carne',
#  'mermelada compota',
#  'guinda confitada',
#  'menta fresco',
#  'fabas',
#  'salsa ostra',
#  'cebollino',
#  'yogur fresa',
#  'ternera',
#  'tofu',
#  'grosellas',
#  'calabacín pepino',
#  'caldo pescado cacito',
#  'wasabi',
#  'rabanitos',
#  'levadura panadería',
#  'salsa sriracha sambal',
#  'zumo fruta pasión',
#  'queso tipo gouda masdaam',
#  'pera conferencia',
#  'agua pan',
#  'pepitas chocolate chocolate rallado azúcar',
#  'agua baño maría',
#  'almendras',
#  'oreja cerdo',
#  'licor naranja',
#  'cayena chile',
#  'cabeza ajo',
#  'pimienta negro tartar',
#  'jengibre fresco postre rallado',
#  'espinaca',
#  'mayonesa',
#  'mozzarella fresco',
#  'tocino tira panceta',
#  'remolacha',
#  'harina quinoa',
#  'cebolla blanca',
#  'chuletas sajonia',
#  'azúcar acabado',
#  'pan torrija rebanada',
#  'jengibre fresco rallado',
#  'hanout',
#  'chile rodaja',
#  'fideos huevo',
#  'guindilla fresco verde rojo',
#  'limón octavo',
#  'cayena guindillita',
#  'azúcar sopera',
#  'almendras fritas',
#  'puerro cm',
#  'coca cola',
#  'pan rallado',
#  'semi',
#  'escarola',
#  'pasta orzo',
#  'espaguetis',
#  'pimiento rojo mezcla color',
#  'cuarto pollo hueso piel',
#  'hierbas',
#  'fresco yogur',
#  'gelatina polvo',
#  'mermelada fresa',
#  'dientes ajo negro',
#  'trigo sarraceno',
#  'salvia fresco',
#  'calabaza cubo',
#  'pan rebanada mortero',
#  'vinagre arroz sidra',
#  'yogur griego',
#  'guindilla preferencia',
#  'ciruela',
#  'surimi',
#  'vinagre jerez pimiento',
#  'ajo fresco',
#  'tomate bote',
#  'queso rulo cabra medallón',
#  'limón',
#  'queso sandwich loncha',
#  'vinagre jerez arroz',
#  'decoración',
#  'judías verde plana',
#  'vermut blanco',
#  'harina espelta integral trigo',
#  'pimiento rojo morrón',
#  'tallarines linguini',
#  'agua arroz sushi',
#  'chocolate negro triturado',
#  'arroz basmati guarnición',
#  'lino',
#  'agua masa madre levadura',
#  'pimiento rojo piquillo',
#  'zumo lima',
#  'pimienta jamaica',
#  'cúrcuma',
#  'aguacate aguacate',
#  'arroz redondo carnaroli arborio',
#  'rúcula canónigo',
#  'tortita arroz',
#  'salvia fresca hoja',
#  'truchas',
#  'harina arroz quinoa trigo sarraceno',
#  'queso cabra rulo',
#  'pasta integral pasta',
#  'leche',
#  'hongos boletus variedad hongo guarnición',
#  'yemas huevo',
#  'pepino mini',
#  'garbanzos',
#  'tomillo fresco postre adobo',
#  'cerveza',
#  'tortillas maíz',
#  'gambones',
#  'mermelada fresa frambuesa',
#  'zumo limón naranja',
#  'fresco',
#  'repollo hojas',
#  'alcachofa corazón conserva',
#  'queso mozzarella',
#  'aceituna',
#  'azúcar aderezo arroz',
#  'azafrán',
#  'vodka',
#  'harissa',
#  'algarroba',
#  'pera',
#  'cacao polvo puro polvo',
#  'sal marina',
#  'ralladura limón',
#  'perejil fresco',
#  'albahaca hoja fresco',
#  'ajo polvo',
#  'semillas mostaza',
#  'azúcar miel',
#  'huevas',
#  'pimiento piquillo guarnición',
#  'seta lengua vaca¨',
#  'fideos número',
#  'panceta dado',
#  'levadura fresco masa mollete',
#  'vino jerez vino',
#  'shichimi togarashi',
#  'brandy whisky',
#  'sumac zumaque',
#  'semillas sésamo bolita',
#  'perejil fresco manojito',
#  'romero fresco',
#  'queso cabra',
#  'masa madre',
#  'pelada largo mitad',
#  'harina trigo sopera',
#  'avellana almendra',
#  'vino málaga',
#  'pimienta molida',
#  'granillo alamendra',
#  'gla',
#  'avellana',
#  'plátano',
#  'ñoquis',
#  'agua caldo verdura',
#  'almendra pelada',
#  'levadura fresca panadería',
#  'jengibre fresco trocito',
#  'granillo almendra',
#  'esencia vainilla azúcar',
#  'crema cacao avellana',
#  'sal aderezo arroz',
#  'maduro',
#  'patata',
#  'queso provolone',
#  'zanco pollo',
#  'lentejas',
#  'tahini',
#  'codorniz',
#  'almendra tostada',
#  'frijol pinta conserva',
#  'caldo verdura',
#  'hielo',
#  'pisingallo',
#  'salsa tabasco',
#  'sal aceituna negro',
#  'pimiento rojo tira conserva',
#  'mantequilla sartén',
#  'pepino',
#  'lechuga',
#  'guindilla verde fresca rojo',
#  'ternera taco',
#  'laurel hoja adobo',
#  'batata',
#  'merluza rodaja',
#  'cogollo lechuga',
#  'patata patata',
#  'papel base sartén',
#  'pimentón vera picante',
#  'azúcar glasé decoración',
#  'alubia conserva',
#  'guindilla cayena',
#  'aceite virgen cebolleta',
#  'cacahuetes miel',
#  'helado vainilla',
#  'orégano',
#  'tomate color',
#  'cabecero lomo',
#  'rabo toro',
#  'queso gruyère',
#  'confit pato',
#  'papada cerdo',
#  'sal mezcla',
#  'miga pan integral',
#  'mezcla especia pan especia',
#  'mantequilla dado',
#  'jamón york loncha',
#  'queso parmesano grana',
#  'queso rallado tipo cheddar',
#  'salmonete',
#  'pimentón picante sopera adobo',
#  'orégano postre adobo',
#  'cabrito hueso',
#  'coñac chorretón',
#  'nabo',
#  'sal',
#  'galletas tipo maría',
#  'salsa tomate',
#  'sirope ágave',
#  'pollo mitad',
#  'vinagre módena',
#  'atún conserva',
#  'guisant',
#  'nuez mezcla',
#  'mostaza dijon',
#  'costilla falda',
#  'pimienta negro grano',
#  'orejones',
#  'rape fresco',
#  'queso raclette loncha',
#  'vinagre sidra jerez',
#  'vinagre vino sidra',
#  'cebollino tallo verde cebolleta',
#  'granada',
#  'harina trigo masa regañás',
#  'puré calabaza',
#  'pinta',
#  'sal gruesa',
#  'chocolate leche negro',
#  'amaretto',
#  'aceitunas kalamata',
#  'queso sandwich',
#  'pan molde',
#  'arroz carnaroli bomba',
#  'crocanti almendra',
#  'vinagre manzana arroz jerez',
#  'azúcar glasé acabado',
#  'capón kg víscera',
#  'kéfir cabra vaca',
#  'masa madre masa madre mollete',
#  'empanadillas',
#  'yogur limón',
#  'caldo pollo verdura agua',
#  'atún fresco tira corta',
#  'pasta',
#  'boletus ejemplar fresco',
#  'repollo',
#  'texturizada agua',
#  'sal maldón cristalito',
#  'lasca taquito',
#  'pulpo pata',
#  'repollo hoja',
#  'pulpo',
#  'pulpo pata tentáculo',
#  'contramuslo pollo piel hueso',
#  'jamón york',
#  'piña rodaja',
#  'frambuesas',
#  'judía pinta conserva',
#  'lacón panceta',
#  'pimienta rosa',
#  'pan rallado 1/2',
#  'mantequilla',
#  'mermelada higo',
#  'espárrago triguero',
#  'entrecot',
#  'nueces',
#  'leche alternativa',
#  'salsa perrins tartar',
#  'contramuslo pollo',
#  'vinagre módena calidad',
#  'queso rallado pesto',
#  'carne',
#  'jamón fina',
#  'pimiento amarillo',
#  'pimiento color',
#  'jamón loncha fina',
#  'bacalao tajada ración',
#  'masa madre mollete masa mollete',
#  'hebra',
#  'yema huevo tartar',
#  'apio',
#  'laurel hojas',
#  'mantequilla cacahuete',
#  'pimiento color verde rojo',
#  'tortillas trigo',
#  'cúrcuma postre marinada aceite',
#  'queso pecorino',
#  'tocino magro',
#  'txakolí',
#  'higo',
#  'crème',
#  'mollejas pollo',
#  'pan naan',
#  'sal masa regañás',
#  'queso pasta',
#  'sidra manzana',
#  'tallarines',
#  'muesli pipa girasol',
#  'aceite coco',
#  'especias',
#  'queso burgos',
#  'chocolate negro postre',
#  'pimienta cayena',
#  'azúcar moreno',
#  'mantequilla tª',
#  'alcaparras',
#  'cebolleta',
#  'frutos rojo',
#  'bacalao fresco',
#  'copo maíz azúcar',
#  'brotes',
#  'brócoli',
#  'sardina arenqu',
#  'pescado filete',
#  'sirope arce',
#  'costilla cerdo',
#  'arroz grano tipo basmati jazmín',
#  'caldo pollo carne',
#  'guindilla rojo',
#  'jamón loncha',
#  'brotes alfalfa',
#  'harina trigo masa madre levadura',
#  'pollo presa',
#  'pimiento verde chile verde',
#  'dulce leche',
#  'coco rallado',
#  'piel limón vainilla canela canela',
#  'laurel hoja',
#  'hierbabuena fresco',
#  'leche almendra avena soja',
#  'pepinillo',
#  'buey mar',
#  'pimientos',
#  'menta fresca',
#  'arroz blanco',
#  'manzana',
#  'lechuga iceberg',
#  'piel naranja',
#  'moras',
#  'mantequilla pan brioche',
#  'huevos tamaño',
#  'codillo cerdo',
#  'piel limón trocito',
#  'rojo',
#  'harina pizza',
#  'cebollino perejil fresco',
#  'jamón taquito mezcla',
#  'harina trigo albóndiga',
#  'judías verde bobby',
#  'leche bebida avena',
#  'aroma almendra',
#  'estrella anís',
#  'lomo cerdo rodaja',
#  'aceitunas',
#  'huevo tamaño',
#  'dientes ajo',
#  'eneldo fresco rama',
#  'queso requesón',
#  'mozzarella fresco bolita mini',
#  'kikos',
#  'masa filo lámina',
#  'conejo partido',
#  'brócoli ramillete',
#  'arroz grano',
#  'yogur azúcar',
#  'salvia fresca',
#  'vino jerez',
#  'perejil fresco cilantro',
#  'vainilla polvo',
#  'pan molde trocito cuerpo',
#  'pan centeno rebanada',
#  'cuscús',
#  'cebolleta verde aro',
#  'vino chorreón',
#  'mozzarella fresca',
#  'caldo verdura pollo',
#  'molde',
#  'pollo corral',
#  'azafrán hebra',
#  'filetes ternera',
#  'masa madre masa regañás',
#  'mostaza dijon salsa mostaza',
#  'clara huevo decoración',
#  'gamba rojo calidad',
#  'maracuyá fruta pasión',
#  'almendra piñón',
#  'naranjas',
#  'aceite virgen cebolla',
#  'cebolla blanca morada',
#  'aceite virgen recipiente',
#  'lentejas rojo',
#  'panko pan rallado',
#  'leche evaporado leche',
#  'zaatar mezcla casera',
#  'bonito fresco',
#  'gasificante repostería',
#  'aguja cerdo',
#  'queso cabra tipo',
#  'leche almendra',
#  'comino grano postre adobo',
#  'zanahoria rallado',
#  'anís',
#  'jarabe azúcar salsa mostaza',
#  'comino',
#  'mantequilla anacardo',
#  'hojaldre redondo',
#  'hojaldre oblea empanadilla',
#  'chipirones',
#  'masa filo',
#  'atún fresco',
#  'coñac',
#  'agua caldo pescado',
#  'leche bebida avena soja almendra',
#  'finas hierbas',
#  'calabacines',
#  'harissa pasta',
#  'espárragos triguero',
#  'alga lámina',
#  'panceta',
#  'harina integral',
#  'ron moreno',
#  'piña conserva',
#  'queso cabrales',
#  'pasta gigli',
#  'aceite virgen empanadilla',
#  'quinoa',
#  'pasta filo lámina',
#  'volován',
#  'contramuslos pollo piel',
#  'ajo rallado',
#  'pisto',
#  'espárrago fresco',
#  'harina maíz',
#  'fraiche',
#  'pechuga pollo medallón',
#  'merluza filete rodaja espina piel',
#  'bicarbonato sódico',
#  'queso gouda',
#  'cava champagne',
#  'kétchup',
#  'semillas sésamo',
#  'pescado roca salado',
#  'pan hogaza día',
#  'harina garbanzo',
#  'vino dulce',
#  'levadura fresca panadería masa madre',
#  'nueces elección',
#  'bacalao espina piel',
#  'crema cacahuete',
#  'guindilla chile rojo fresco semilla',
#  'brotes apio hoja',
#  'pacharán',
#  'mermelada fruto rojo',
#  'extracto vainilla',
#  'clara huevo',
#  'nutella',
#  'fromage blanc queso queso crema',
#  'agua caldo alubia',
#  'harina quinoa trigo sarraceno garbanzo',
#  'queso crema',
#  'clavo 1/8',
#  'harina trigo uso',
#  'alcachofa',
#  'hojaldre',
#  'levadura panadería masa madre levadura',
#  'soja texturizada',
#  'bogavante',
#  'ternera pollo filete',
#  'harina avena',
#  'sirope sopera',
#  'fresa tamaño',
#  'leche bebida soja avena',
#  'mantequilla sal',
#  'mantequilla punto',
#  'cebolla polvo',
#  'chocolate negro azúcar',
#  'caldo pollo verdura',
#  'chocolate fondant',
#  'sal maldón escama',
#  'queso cabra medallón',
#  'semillas amapola',
#  'salsa perrins',
#  'pechuga pollo dadito',
#  'sofrito casero',
#  'panela azúcar',
#  'carne cerdo',
#  'salsa asiática pescado marinada',
#  'hinojo fresco',
#  'caballa',
#  'aceite virgen sopera tartar',
#  'queso mozzarella emmental rallado',
#  'harina espelta integral',
#  'aceite girasol extra molde silicona',
#  'berenjena',
#  'panko',
#  'chufas',
#  'chocolate candy mealts rojo',
#  'sirope arce miel',
#  'rebanada pan',
#  'mollejas ternera',
#  'zanahoria',
#  'polvo',
#  'bacalao salazón casa',
#  'aceite virgen ingrediente',
#  'solomillo cerdo',
#  'morcillo',
#  'paprika polvo',
#  'panela',
#  'limón tira piel',
#  'pera madura',
#  'extracto vainilla semilla vaina',
#  'aceite virgen patata',
#  'piñones',
#  'arenque arencón conserva',
#  'carne cordero ternera pollo',
#  'ralladura naranja limón',
#  'harina fuerza masa pan',
#  'harina trigo sarraceno',
#  'sal escama tartar',
#  'redondo pavo',
#  'champiñones portobello',
#  'masa pizza',
#  'atún fresco filete',
#  'guacamole casero',
#  'sobras plato pasta',
#  'zumo piña',
#  'piel naranja rallado',
#  'pan torrija',
#  'aceite girasol mitad leche',
#  'queso queso crema',
#  'nuez',
#  'seitán filete',
#  'aceite virgen masa pan',
#  'caldo pollo',
#  'espárrago conserva',
#  'levadura',
#  'harina trigo',
#  'garbanzo',
#  'arroz grano día',
#  'trisol',
#  'albahaca albahaca fresca flor',
#  'leche coco',
#  'mezclum',
#  'ciruelas',
#  'pimienta blanca',
#  'salsa bechamel',
#  'queso camembert',
#  'galletas tipo digestive',
#  'buttermilk leche',
#  'pimiento verde ensalada guarnición',
#  'libro',
#  'lomo bacalao skrei',
#  'salsa asiática pescado',
#  'maíz grano',
#  'dátiles hueso',
#  'pistachos',
#  'aceite virgen girasol',
#  'margarina aceite coco',
#  'vermut rojo',
#  'tortilla trigo',
#  'zumo lima limón',
#  'semillas lino',
#  'frijoles',
#  'chile copo',
#  'mazapán',
#  'pimentón',
#  'mermelada frambuesa',
#  'manteca cerdo masa mollete',
#  'vinagre manzana arroz',
#  'azúcar',
#  'albahaca albahaca',
#  'aceite virgen extra',
#  'brandy coñac',
#  'chocolate repostería',
#  'boquerones vinagre',
#  'chistorra',
#  'baking powder royal',
#  'kumquat',
#  'agua caramelo ml',
#  'azúcar moreno marinada',
#  'harina fuerza masa madre',
#  'masa filo hoja',
#  'chorizo oreado',
#  'piña',
#  'verdura',
#  'aceite girasol abundancia',
#  'sazonador burrito taco',
#  'pimienta blanca negro',
#  'materia',
#  'harina trigo miga',
#  'perejil fresco abundancia',
#  'clara huevo lonchas',
#  'queso roquefort',
#  'salsa soja sal',
#  'harina',
#  'naranja zumo',
#  'sardinas fresco',
#  'cobertura tara polvo',
#  'vino adobo',
#  'rape tajada',
#  'tomate rama',
#  'pimienta negro grano baya',
#  'lomo cerdo',
#  'queso oaxaca loncha',
#  'melocotón rojo',
#  'crema castaña',
#  'proteína polvo deportista proteína',
#  'tipo string barrita palito mozzarella queso',
#  'pan barra',
#  'leche bebida',
#  'piel limón tira',
#  'agua oreja',
#  'salmón fresco',
#  'azúcar caña',
#  'manzanas',
#  'cilantro grano',
#  'perejil',
#  'pimiento',
#  'redondo ternera',
#  'hojaldre lámina',
#  'papaya',
#  'guindilla verde',
#  'mafaldine tipo pasta largo pasta',
#  'mozzarella fresca mini mozzarella',
#  'leche mezcla',
#  'maíz',
#  'mini mozzarella fresco',
#  'pepitas chocolate',
#  'mandarina conserva',
#  'fruta confitada',
#  'caramelo casero molde',
#  'calamar',
#  'pan chapata calidad',
#  'azúcar caña integral',
#  'yema huevo',
#  'azúcar coco',
#  'limón ralladura',
#  'pimiento rojo',
#  'azúcar caramelo',
#  'vino montilla moriles',
#  'coles bruselas',
#  'aceite virgen patata pimiento',
#  'farfalle pasta',
#  'mango 1/3',
#  'pan hogaza rebanada',
#  'trocito risotto',
#  'crocanti avellana',
#  'penca',
#  'jamón',
#  'galletas oreo',
#  'salsa tomate tomate',
#  'grana',
#  'salsa soja',
#  'langostino',
#  'mantequilla crep',
#  'aceite virgen patata chuleta pimiento',
#  'pasta pimiento cucharado pasta',
#  'rama',
#  'aceite virgen adobo',
#  'chile',
#  'levadura panadería rasa',
#  'criadillas cordero',
#  'mejillones',
#  'fruta elección',
#  'fruta',
#  'huevo curd',
#  'avellanas',
#  'pan rodaja',
#  'chile rojo fresco',
#  'levadura panadería masa madre',
#  'curry',
#  'ajo ajo polvo',
#  'alubias',
#  'salsa chimichurri',
#  'canela canela rama',
#  'curry 1/2',
#  'aguardiente licor',
#  'especias bayas pimienta semilla cilantro cúrcuma cardamomo marinada',
#  'huevos',
#  'aceituna negro verde',
#  'caldo carne pollo',
#  'brotes soja',
#  'penne macarrón',
#  'láminas pasta lasaña',
#  'anacardo',
#  'almendra bastones',
#  'masa',
#  'solomillo',
#  'queso vacherin fribourgeois',
#  'contramuslo pollo hueso piel',
#  'emperador filete rodaja',
#  'salsa pescado',
#  'azúcar confetti',
#  'guisantes',
#  'orégano fresco',
#  'aceituna hueso',
#  'cacao polvo',
#  'langostinos',
#  'champiñones',
#  'puerro',
#  'mango',
#  'picona mojo',
#  'cilantro fresco perejil',
#  'dientes ajo adobo',
#  'arándano fresco',
#  'albahaca albahaca fresco',
#  'harina trigo masa mollete',
#  'sal ajo',
#  'ciruela rojo',
#  'plancha hojaldre',
#  'espárrago triguero medio',
#  'caldo verdura agua',
#  'cilantro fresco',
#  'avena',
#  'lima',
#  'agua',
#  'pimiento piquillo',
#  'harina trigo medida yogur',
#  'pescado',
#  'kiwis madura',
#  'choi',
#  'carne ternera',
#  'hinojo fresco trocito',
#  'langosta',
#  'queso maasdam',
#  'espinaca fresco',
#  'almendra granillo',
#  'salsa wok',
#  'requesón',
#  'chicharro',
#  'pollo',
#  'flores comestibl',
#  'avena copo',
#  'tomillo fresco rama',
#  'hierbabuena',
#  'salsa asiática pescado soja',
#  'chocolate leche cobertura',
#  'caldo pescado',
#  'harina repostería arroz',
#  'gulas',
#  'sesos cordero',
#  'semillas sésamo tostadas',
#  'perejil fresco rama',
#  'fresa',
#  'champiñones seta fresco',
#  'azúcar glasé nata',
#  'queso',
#  'queso cabra pasta duro pasta',
#  'masa filo brick',
#  'pimiento verde rojo',
#  'harina fritura',
#  'chips chocolate negro',
#  'agua gas',
#  'solomillo medallón',
#  'copo avena',
#  'rallado',
#  'pimienta rosa baya',
#  'chocolate',
#  'yogur fruta bosque',
#  'brandy',
#  'fresco quark',
#  'bicarbonato sódico azúcar',
#  'rúcula',
#  'azafrán pimentón',
#  'harina trigo masa madre',
#  'nata',
#  'uvas pasa',
#  'polenta',
#  'ají amarillo',
#  'maicena',
#  'coliflor',
#  'vinagre sidra',
#  'pasta tipo',
#  'cerezas picota',
#  'ojos azúcar',
#  'arroz sushi arroz sushi',
#  'mantequilla curd',
#  'churrasco ternera',
#  'lengua ternera',
#  'clavos',
#  'azúcar edulcorante',
#  'cayena',
#  'levadura fresco',
#  'harina trigo hojaldre',
#  'chocolate cobertura',
#  'papel medida plancha',
#  'pimienta negro',
#  'mantequilla molde',
#  'salsa mostaza',
#  'agua masa pan',
#  'chocolate cobertura decoración',
#  'kale hoja',
#  'caldo carne',
#  'láminas pasta canelón',
#  'especia',
#  'chalota',
#  'mazorca maíz baby',
#  'lechuga hoja',
#  'placas lasaña',
#  'nata mg',
#  'agua masa regañás',
#  'licor cereza kirsch',
#  'espinaca fresca',
#  'pan bocadillo',
#  'pan',
#  'fresa pedúnculo',
#  'placas lasaña precocida',
#  'chopito puntillita',
#  'pimiento verde',
#  'jengibre molido',
#  'flor',
#  'puerro rodaja',
#  'ralladura limón lima',
#  'vinagre jerez',
#  'agua adobo',
#  'conejo',
#  'cacao polvo rasa',
#  'clavo cuarto',
#  'pasta pimiento harissa',
#  'té matcha',
#  'tomate entero',
#  'leche nata',
#  'aceite oliva',
#  'ron',
#  'yogur bote',
#  'ralladura limón quesillo',
#  'zumo tomate',
#  'ñora',
#  'leche almendra soja avena coco',
#  'sal masa pan',
#  'atún aceite',
#  'azafrán sobre hebra',
#  'salchichas fresco longaniza carnicería',
#  'sal adobo',
#  'salsa acompañamiento',
#  'crème fraîche nata',
#  'cayena guindilla',
#  'masa madre masa pan',
#  'kokotxas rape',
#  'hierba',
#  'calabacín',
#  'nesquik',
#  ...}
